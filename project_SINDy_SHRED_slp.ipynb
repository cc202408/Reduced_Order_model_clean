# %%
#This file is modified from the https://github.com/gaoliyao/sindy-shred/blob/main/sst_sindy_shred.ipynb

# %%
import sys
print(sys.executable)
sys.path.insert(0, './SINDy_SHRED') #import SINDy_SHRED

import numpy as np
from processdata import TimeSeriesDataset

import torch
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import sindy
import os

import xarray as xr

import cartopy.crs as ccrs  #for plot the coastline 
import cartopy.feature as cfeature 

import random
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
torch.cuda.manual_seed(0)
# torch.backends.cudnn.deterministic = True
# torch.backends.cudnn.benchmark = False

os.environ["CUDA_VISIBLE_DEVICES"]="0"

num_sensors = 250
lags = 52

#We load the data and assign it to the X matrix

# load data
ds = xr.open_dataset('./project_Data/slp.nc') # change to 't2m.nc' for temperature data
slp = ds['msl'] # 'msl' is the variable name for slp, change to 't2m' for temperature data

# get longitude values
dlongitude = ds['longitude']
lon = dlongitude.values

# get latitude values 
dlatitude = ds['latitude']
lat = dlatitude.values

# mesh for (lo,lat)
lon2d, lat2d = np.meshgrid(lon, lat)

# dimensions of data
n_samples = slp.values.shape[0]
n_lat = 101 
n_lon = 161
shape = (n_samples, n_lat, n_lon)

# define reshape (n_lat,n_lon) <-- (n_lat*n_lon,1)
def reshape_mode(mode_vec):
    return mode_vec.reshape(n_lat, n_lon)

# transform it into (n_lat * n_lon, n_samples) from ds (n_samples, n_lat, n_lon)
load_X = slp.values.reshape(slp.shape[0], -1)
n = load_X.shape[0]
m = load_X.shape[1]
print(load_X.shape)

# fixed sensor position
# grid_dim = int(np.sqrt(num_sensors))
# lat_indices = np.linspace(0, n_lat - 1, grid_dim, dtype=int)
# lon_indices = np.linspace(0, n_lon - 1, grid_dim, dtype=int)
# sensor_coords = [(lat, lon) for lat in lat_indices for lon in lon_indices]
# sensor_locations = np.array([lat * n_lon + lon for lat, lon in sensor_coords])
# num_sensors =  grid_dim * grid_dim

# random sensor position
sensor_locations = np.random.choice(m, size=num_sensors, replace=False)
# Out:
# /home/lc/Desktop/ME5311/myvenvME5311/bin/python
# (16071, 16261)

# %%
#filter
from scipy.signal import butter, filtfilt

def lowpass_filter(data, cutoff=0.1, fs=1.0, order=5):
   b, a = butter(order, cutoff / (0.5 * fs), btype='low')
   return filtfilt(b, a, data, axis=0)
    
load_X  = lowpass_filter(load_X[:, :])

#sample every 7 times
transformed_X1  = load_X[::7,:]
n_samples = transformed_X1.shape[0]
n = n_samples
print(transformed_X1.shape)

sub_index_X = transformed_X1[:,sensor_locations]
fig, ax = plt.subplots(5)
for i in range(5):
    ax[i].plot(sub_index_X[:,i])
# Out:
# (2296, 16261)

# %%
#train/validation/test 
Ndata = n_samples - lags
indices = np.arange(Ndata)

train_size = int(Ndata * 0.8)   # 80%
valid_size = int(Ndata * 0.1)   # 10%
test_size  = Ndata - train_size - valid_size  # 10%

train_indices = indices[:train_size]                   
valid_indices = indices[train_size : train_size + valid_size]  
test_indices  = indices[train_size + valid_size :]     

print(len(train_indices))
print(len(valid_indices))
print(len(test_indices))

sc = MinMaxScaler()
sc = sc.fit(transformed_X1[train_indices])
transformed_X = sc.transform(transformed_X1)
# Out:
# 1795
# 224
# 225

# %%
### Generate input sequences to a SHRED model
all_data_in = np.zeros((n - lags, lags, num_sensors))
for i in range(len(all_data_in)):
    all_data_in[i] = transformed_X[i:i+lags, sensor_locations]

### Generate training validation and test datasets both for reconstruction of states and forecasting sensors
device = 'cuda' if torch.cuda.is_available() else 'cpu'

train_data_in = torch.tensor(all_data_in[train_indices], dtype=torch.float32).to(device)
valid_data_in = torch.tensor(all_data_in[valid_indices], dtype=torch.float32).to(device)
test_data_in = torch.tensor(all_data_in[test_indices], dtype=torch.float32).to(device)

### -1 to have output be at the same time as final sensor measurements
train_data_out = torch.tensor(transformed_X[train_indices + lags - 1], dtype=torch.float32).to(device)
valid_data_out = torch.tensor(transformed_X[valid_indices + lags - 1], dtype=torch.float32).to(device)
test_data_out = torch.tensor(transformed_X[test_indices + lags - 1], dtype=torch.float32).to(device)

train_dataset = TimeSeriesDataset(train_data_in, train_data_out)
valid_dataset = TimeSeriesDataset(valid_data_in, valid_data_out)
test_dataset = TimeSeriesDataset(test_data_in, test_data_out)

print(train_data_in.shape)
# Out:
# torch.Size([1795, 52, 250])

# %%
#SINDy library
latent_dim = 3
poly_order = 3
include_sine = False
library_dim = sindy.library_size(latent_dim, poly_order, include_sine, True)

# %%
#training
import sindy_shred
shred = sindy_shred.SINDy_SHRED(num_sensors, m, hidden_size=latent_dim, hidden_layers=2, l1=350, l2=400, dropout=0.1, 
                                 library_dim=library_dim, poly_order=poly_order, include_sine=include_sine, dt=1.0/lags*0.1, layer_norm=False).to(device)

validation_errors = sindy_shred.fit(shred, train_dataset, valid_dataset, batch_size=128, num_epochs=1000, lr=1e-3, verbose=True, threshold=0.25, patience=5, sindy_regularization=10.0, optimizer="AdamW", thres_epoch=100)
# Out:
# 1 : tensor(0.0252, device='cuda:0', grad_fn=<AddBackward0>)
# 2 : tensor(0.0126, device='cuda:0', grad_fn=<AddBackward0>)
# 3 : tensor(0.0123, device='cuda:0', grad_fn=<AddBackward0>)
# 4 : tensor(0.0119, device='cuda:0', grad_fn=<AddBackward0>)
# 5 : tensor(0.0113, device='cuda:0', grad_fn=<AddBackward0>)
# 6 : tensor(0.0124, device='cuda:0', grad_fn=<AddBackward0>)
# 7 : tensor(0.0134, device='cuda:0', grad_fn=<AddBackward0>)
# 8 : tensor(0.0132, device='cuda:0', grad_fn=<AddBackward0>)
# 9 : tensor(0.0113, device='cuda:0', grad_fn=<AddBackward0>)
# 10 : tensor(0.0120, device='cuda:0', grad_fn=<AddBackward0>)
# 11 : tensor(0.0118, device='cuda:0', grad_fn=<AddBackward0>)
# 12 : tensor(0.0110, device='cuda:0', grad_fn=<AddBackward0>)
# 13 : tensor(0.0120, device='cuda:0', grad_fn=<AddBackward0>)
# 14 : tensor(0.0106, device='cuda:0', grad_fn=<AddBackward0>)
# 15 : tensor(0.0113, device='cuda:0', grad_fn=<AddBackward0>)
# 16 : tensor(0.0107, device='cuda:0', grad_fn=<AddBackward0>)
# 17 : tensor(0.0117, device='cuda:0', grad_fn=<AddBackward0>)
# 18 : tensor(0.0104, device='cuda:0', grad_fn=<AddBackward0>)
# 19 : tensor(0.0102, device='cuda:0', grad_fn=<AddBackward0>)
# 20 : tensor(0.0119, device='cuda:0', grad_fn=<AddBackward0>)
# 21 : tensor(0.0104, device='cuda:0', grad_fn=<AddBackward0>)
# 22 : tensor(0.0108, device='cuda:0', grad_fn=<AddBackward0>)
# 23 : tensor(0.0097, device='cuda:0', grad_fn=<AddBackward0>)
# 24 : tensor(0.0103, device='cuda:0', grad_fn=<AddBackward0>)
# 25 : tensor(0.0108, device='cuda:0', grad_fn=<AddBackward0>)
# 26 : tensor(0.0097, device='cuda:0', grad_fn=<AddBackward0>)
# 27 : tensor(0.0104, device='cuda:0', grad_fn=<AddBackward0>)
# 28 : tensor(0.0109, device='cuda:0', grad_fn=<AddBackward0>)
# 29 : tensor(0.0102, device='cuda:0', grad_fn=<AddBackward0>)
# 30 : tensor(0.0110, device='cuda:0', grad_fn=<AddBackward0>)
# 31 : tensor(0.0097, device='cuda:0', grad_fn=<AddBackward0>)
# 32 : tensor(0.0111, device='cuda:0', grad_fn=<AddBackward0>)
# 33 : tensor(0.0105, device='cuda:0', grad_fn=<AddBackward0>)
# 34 : tensor(0.0119, device='cuda:0', grad_fn=<AddBackward0>)
# 35 : tensor(0.0117, device='cuda:0', grad_fn=<AddBackward0>)
# 36 : tensor(0.0114, device='cuda:0', grad_fn=<AddBackward0>)
# 37 : tensor(0.0100, device='cuda:0', grad_fn=<AddBackward0>)
# 38 : tensor(0.0092, device='cuda:0', grad_fn=<AddBackward0>)
# 39 : tensor(0.0097, device='cuda:0', grad_fn=<AddBackward0>)
# 40 : tensor(0.0105, device='cuda:0', grad_fn=<AddBackward0>)
# 41 : tensor(0.0111, device='cuda:0', grad_fn=<AddBackward0>)
# 42 : tensor(0.0099, device='cuda:0', grad_fn=<AddBackward0>)
# 43 : tensor(0.0115, device='cuda:0', grad_fn=<AddBackward0>)
# 44 : tensor(0.0136, device='cuda:0', grad_fn=<AddBackward0>)
# 45 : tensor(0.0135, device='cuda:0', grad_fn=<AddBackward0>)
# 46 : tensor(0.0111, device='cuda:0', grad_fn=<AddBackward0>)
# 47 : tensor(0.0145, device='cuda:0', grad_fn=<AddBackward0>)
# 48 : tensor(0.0129, device='cuda:0', grad_fn=<AddBackward0>)
# 49 : tensor(0.0176, device='cuda:0', grad_fn=<AddBackward0>)
# 50 : tensor(0.0155, device='cuda:0', grad_fn=<AddBackward0>)
# 51 : tensor(0.0205, device='cuda:0', grad_fn=<AddBackward0>)
# 52 : tensor(0.0215, device='cuda:0', grad_fn=<AddBackward0>)
# 53 : tensor(0.0150, device='cuda:0', grad_fn=<AddBackward0>)
# 54 : tensor(0.0132, device='cuda:0', grad_fn=<AddBackward0>)
# 55 : tensor(0.0120, device='cuda:0', grad_fn=<AddBackward0>)
# 56 : tensor(0.0120, device='cuda:0', grad_fn=<AddBackward0>)
# 57 : tensor(0.0126, device='cuda:0', grad_fn=<AddBackward0>)
# 58 : tensor(0.0130, device='cuda:0', grad_fn=<AddBackward0>)
# 59 : tensor(0.0142, device='cuda:0', grad_fn=<AddBackward0>)
# 60 : tensor(0.0127, device='cuda:0', grad_fn=<AddBackward0>)
# 61 : tensor(0.0122, device='cuda:0', grad_fn=<AddBackward0>)
# 62 : tensor(0.0143, device='cuda:0', grad_fn=<AddBackward0>)
# 63 : tensor(0.0109, device='cuda:0', grad_fn=<AddBackward0>)
# 64 : tensor(0.0102, device='cuda:0', grad_fn=<AddBackward0>)
# 65 : tensor(0.0120, device='cuda:0', grad_fn=<AddBackward0>)
# 66 : tensor(0.0125, device='cuda:0', grad_fn=<AddBackward0>)
# 67 : tensor(0.0098, device='cuda:0', grad_fn=<AddBackward0>)
# 68 : tensor(0.0114, device='cuda:0', grad_fn=<AddBackward0>)
# 69 : tensor(0.0114, device='cuda:0', grad_fn=<AddBackward0>)
# 70 : tensor(0.0121, device='cuda:0', grad_fn=<AddBackward0>)
# 71 : tensor(0.0098, device='cuda:0', grad_fn=<AddBackward0>)
# 72 : tensor(0.0095, device='cuda:0', grad_fn=<AddBackward0>)
# 73 : tensor(0.0108, device='cuda:0', grad_fn=<AddBackward0>)
# 74 : tensor(0.0133, device='cuda:0', grad_fn=<AddBackward0>)
# 75 : tensor(0.0119, device='cuda:0', grad_fn=<AddBackward0>)
# 76 : tensor(0.0102, device='cuda:0', grad_fn=<AddBackward0>)
# 77 : tensor(0.0103, device='cuda:0', grad_fn=<AddBackward0>)
# 78 : tensor(0.0095, device='cuda:0', grad_fn=<AddBackward0>)
# 79 : tensor(0.0110, device='cuda:0', grad_fn=<AddBackward0>)
# 80 : tensor(0.0099, device='cuda:0', grad_fn=<AddBackward0>)
# 81 : tensor(0.0109, device='cuda:0', grad_fn=<AddBackward0>)
# 82 : tensor(0.0115, device='cuda:0', grad_fn=<AddBackward0>)
# 83 : tensor(0.0111, device='cuda:0', grad_fn=<AddBackward0>)
# 84 : tensor(0.0104, device='cuda:0', grad_fn=<AddBackward0>)
# 85 : tensor(0.0100, device='cuda:0', grad_fn=<AddBackward0>)
# 86 : tensor(0.0099, device='cuda:0', grad_fn=<AddBackward0>)
# 87 : tensor(0.0096, device='cuda:0', grad_fn=<AddBackward0>)
# 88 : tensor(0.0086, device='cuda:0', grad_fn=<AddBackward0>)
# 89 : tensor(0.0110, device='cuda:0', grad_fn=<AddBackward0>)
# 90 : tensor(0.0107, device='cuda:0', grad_fn=<AddBackward0>)
# 91 : tensor(0.0100, device='cuda:0', grad_fn=<AddBackward0>)
# 92 : tensor(0.0103, device='cuda:0', grad_fn=<AddBackward0>)
# 93 : tensor(0.0095, device='cuda:0', grad_fn=<AddBackward0>)
# 94 : tensor(0.0083, device='cuda:0', grad_fn=<AddBackward0>)
# 95 : tensor(0.0090, device='cuda:0', grad_fn=<AddBackward0>)
# 96 : tensor(0.0094, device='cuda:0', grad_fn=<AddBackward0>)
# 97 : tensor(0.0115, device='cuda:0', grad_fn=<AddBackward0>)
# 98 : tensor(0.0098, device='cuda:0', grad_fn=<AddBackward0>)
# 99 : tensor(0.0097, device='cuda:0', grad_fn=<AddBackward0>)
# 100 : tensor(0.0110, device='cuda:0', grad_fn=<AddBackward0>)
# Training epoch 100
# Error tensor(0.2056, device='cuda:0')
# 101 : tensor(0.0113, device='cuda:0', grad_fn=<AddBackward0>)
# 102 : tensor(0.0092, device='cuda:0', grad_fn=<AddBackward0>)
# 103 : tensor(0.0090, device='cuda:0', grad_fn=<AddBackward0>)
# 104 : tensor(0.0101, device='cuda:0', grad_fn=<AddBackward0>)
# 105 : tensor(0.0104, device='cuda:0', grad_fn=<AddBackward0>)
# 106 : tensor(0.0099, device='cuda:0', grad_fn=<AddBackward0>)
# 107 : tensor(0.0091, device='cuda:0', grad_fn=<AddBackward0>)
# 108 : tensor(0.0094, device='cuda:0', grad_fn=<AddBackward0>)
# 109 : tensor(0.0105, device='cuda:0', grad_fn=<AddBackward0>)
# 110 : tensor(0.0088, device='cuda:0', grad_fn=<AddBackward0>)
# 111 : tensor(0.0095, device='cuda:0', grad_fn=<AddBackward0>)
# 112 : tensor(0.0121, device='cuda:0', grad_fn=<AddBackward0>)
# 113 : tensor(0.0127, device='cuda:0', grad_fn=<AddBackward0>)
# 114 : tensor(0.0107, device='cuda:0', grad_fn=<AddBackward0>)
# 115 : tensor(0.0094, device='cuda:0', grad_fn=<AddBackward0>)
# 116 : tensor(0.0115, device='cuda:0', grad_fn=<AddBackward0>)
# 117 : tensor(0.0107, device='cuda:0', grad_fn=<AddBackward0>)
# 118 : tensor(0.0112, device='cuda:0', grad_fn=<AddBackward0>)
# 119 : tensor(0.0091, device='cuda:0', grad_fn=<AddBackward0>)
# 120 : tensor(0.0107, device='cuda:0', grad_fn=<AddBackward0>)
# 121 : tensor(0.0101, device='cuda:0', grad_fn=<AddBackward0>)
# 122 : tensor(0.0096, device='cuda:0', grad_fn=<AddBackward0>)
# 123 : tensor(0.0088, device='cuda:0', grad_fn=<AddBackward0>)
# 124 : tensor(0.0114, device='cuda:0', grad_fn=<AddBackward0>)
# 125 : tensor(0.0093, device='cuda:0', grad_fn=<AddBackward0>)
# 126 : tensor(0.0114, device='cuda:0', grad_fn=<AddBackward0>)
# 127 : tensor(0.0118, device='cuda:0', grad_fn=<AddBackward0>)
# 128 : tensor(0.0109, device='cuda:0', grad_fn=<AddBackward0>)
# 129 : tensor(0.0089, device='cuda:0', grad_fn=<AddBackward0>)
# 130 : tensor(0.0101, device='cuda:0', grad_fn=<AddBackward0>)
# 131 : tensor(0.0115, device='cuda:0', grad_fn=<AddBackward0>)
# 132 : tensor(0.0095, device='cuda:0', grad_fn=<AddBackward0>)
# 133 : tensor(0.0089, device='cuda:0', grad_fn=<AddBackward0>)
# 134 : tensor(0.0087, device='cuda:0', grad_fn=<AddBackward0>)
# 135 : tensor(0.0089, device='cuda:0', grad_fn=<AddBackward0>)
# 136 : tensor(0.0091, device='cuda:0', grad_fn=<AddBackward0>)
# 137 : tensor(0.0094, device='cuda:0', grad_fn=<AddBackward0>)
# 138 : tensor(0.0112, device='cuda:0', grad_fn=<AddBackward0>)
# 139 : tensor(0.0095, device='cuda:0', grad_fn=<AddBackward0>)
# 140 : tensor(0.0119, device='cuda:0', grad_fn=<AddBackward0>)
# 141 : tensor(0.0096, device='cuda:0', grad_fn=<AddBackward0>)
# 142 : tensor(0.0092, device='cuda:0', grad_fn=<AddBackward0>)
# 143 : tensor(0.0090, device='cuda:0', grad_fn=<AddBackward0>)
# 144 : tensor(0.0092, device='cuda:0', grad_fn=<AddBackward0>)
# 145 : tensor(0.0101, device='cuda:0', grad_fn=<AddBackward0>)
# 146 : tensor(0.0078, device='cuda:0', grad_fn=<AddBackward0>)
# 147 : tensor(0.0111, device='cuda:0', grad_fn=<AddBackward0>)
# 148 : tensor(0.0105, device='cuda:0', grad_fn=<AddBackward0>)
# 149 : tensor(0.0096, device='cuda:0', grad_fn=<AddBackward0>)
# 150 : tensor(0.0103, device='cuda:0', grad_fn=<AddBackward0>)
# 151 : tensor(0.0119, device='cuda:0', grad_fn=<AddBackward0>)
# 152 : tensor(0.0097, device='cuda:0', grad_fn=<AddBackward0>)
# 153 : tensor(0.0088, device='cuda:0', grad_fn=<AddBackward0>)
# 154 : tensor(0.0091, device='cuda:0', grad_fn=<AddBackward0>)
# 155 : tensor(0.0090, device='cuda:0', grad_fn=<AddBackward0>)
# 156 : tensor(0.0087, device='cuda:0', grad_fn=<AddBackward0>)
# 157 : tensor(0.0091, device='cuda:0', grad_fn=<AddBackward0>)
# 158 : tensor(0.0099, device='cuda:0', grad_fn=<AddBackward0>)
# 159 : tensor(0.0105, device='cuda:0', grad_fn=<AddBackward0>)
# 160 : tensor(0.0098, device='cuda:0', grad_fn=<AddBackward0>)
# 161 : tensor(0.0086, device='cuda:0', grad_fn=<AddBackward0>)
# 162 : tensor(0.0085, device='cuda:0', grad_fn=<AddBackward0>)
# 163 : tensor(0.0086, device='cuda:0', grad_fn=<AddBackward0>)
# 164 : tensor(0.0077, device='cuda:0', grad_fn=<AddBackward0>)
# 165 : tensor(0.0089, device='cuda:0', grad_fn=<AddBackward0>)
# 166 : tensor(0.0083, device='cuda:0', grad_fn=<AddBackward0>)
# 167 : tensor(0.0086, device='cuda:0', grad_fn=<AddBackward0>)
# 168 : tensor(0.0087, device='cuda:0', grad_fn=<AddBackward0>)
# 169 : tensor(0.0088, device='cuda:0', grad_fn=<AddBackward0>)
# 170 : tensor(0.0082, device='cuda:0', grad_fn=<AddBackward0>)
# 171 : tensor(0.0089, device='cuda:0', grad_fn=<AddBackward0>)
# 172 : tensor(0.0084, device='cuda:0', grad_fn=<AddBackward0>)
# 173 : tensor(0.0105, device='cuda:0', grad_fn=<AddBackward0>)
# 174 : tensor(0.0084, device='cuda:0', grad_fn=<AddBackward0>)
# 175 : tensor(0.0089, device='cuda:0', grad_fn=<AddBackward0>)
# 176 : tensor(0.0084, device='cuda:0', grad_fn=<AddBackward0>)
# 177 : tensor(0.0070, device='cuda:0', grad_fn=<AddBackward0>)
# 178 : tensor(0.0081, device='cuda:0', grad_fn=<AddBackward0>)
# 179 : tensor(0.0098, device='cuda:0', grad_fn=<AddBackward0>)
# 180 : tensor(0.0107, device='cuda:0', grad_fn=<AddBackward0>)
# 181 : tensor(0.0069, device='cuda:0', grad_fn=<AddBackward0>)
# 182 : tensor(0.0078, device='cuda:0', grad_fn=<AddBackward0>)
# 183 : tensor(0.0077, device='cuda:0', grad_fn=<AddBackward0>)
# 184 : tensor(0.0089, device='cuda:0', grad_fn=<AddBackward0>)
# 185 : tensor(0.0083, device='cuda:0', grad_fn=<AddBackward0>)
# 186 : tensor(0.0091, device='cuda:0', grad_fn=<AddBackward0>)
# 187 : tensor(0.0097, device='cuda:0', grad_fn=<AddBackward0>)
# 188 : tensor(0.0076, device='cuda:0', grad_fn=<AddBackward0>)
# 189 : tensor(0.0076, device='cuda:0', grad_fn=<AddBackward0>)
# 190 : tensor(0.0081, device='cuda:0', grad_fn=<AddBackward0>)
# 191 : tensor(0.0090, device='cuda:0', grad_fn=<AddBackward0>)
# 192 : tensor(0.0072, device='cuda:0', grad_fn=<AddBackward0>)
# 193 : tensor(0.0098, device='cuda:0', grad_fn=<AddBackward0>)
# 194 : tensor(0.0087, device='cuda:0', grad_fn=<AddBackward0>)
# 195 : tensor(0.0081, device='cuda:0', grad_fn=<AddBackward0>)
# 196 : tensor(0.0096, device='cuda:0', grad_fn=<AddBackward0>)
# 197 : tensor(0.0099, device='cuda:0', grad_fn=<AddBackward0>)
# 198 : tensor(0.0094, device='cuda:0', grad_fn=<AddBackward0>)
# 199 : tensor(0.0086, device='cuda:0', grad_fn=<AddBackward0>)
# 200 : tensor(0.0075, device='cuda:0', grad_fn=<AddBackward0>)
# Training epoch 200
# Error tensor(0.1942, device='cuda:0')
# 201 : tensor(0.0074, device='cuda:0', grad_fn=<AddBackward0>)
# 202 : tensor(0.0086, device='cuda:0', grad_fn=<AddBackward0>)
# 203 : tensor(0.0089, device='cuda:0', grad_fn=<AddBackward0>)
# 204 : tensor(0.0071, device='cuda:0', grad_fn=<AddBackward0>)
# 205 : tensor(0.0069, device='cuda:0', grad_fn=<AddBackward0>)
# 206 : tensor(0.0075, device='cuda:0', grad_fn=<AddBackward0>)
# 207 : tensor(0.0075, device='cuda:0', grad_fn=<AddBackward0>)
# 208 : tensor(0.0099, device='cuda:0', grad_fn=<AddBackward0>)
# 209 : tensor(0.0084, device='cuda:0', grad_fn=<AddBackward0>)
# 210 : tensor(0.0081, device='cuda:0', grad_fn=<AddBackward0>)
# 211 : tensor(0.0084, device='cuda:0', grad_fn=<AddBackward0>)
# 212 : tensor(0.0087, device='cuda:0', grad_fn=<AddBackward0>)
# 213 : tensor(0.0078, device='cuda:0', grad_fn=<AddBackward0>)
# 214 : tensor(0.0088, device='cuda:0', grad_fn=<AddBackward0>)
# 215 : tensor(0.0082, device='cuda:0', grad_fn=<AddBackward0>)
# 216 : tensor(0.0077, device='cuda:0', grad_fn=<AddBackward0>)
# 217 : tensor(0.0093, device='cuda:0', grad_fn=<AddBackward0>)
# 218 : tensor(0.0084, device='cuda:0', grad_fn=<AddBackward0>)
# 219 : tensor(0.0082, device='cuda:0', grad_fn=<AddBackward0>)
# 220 : tensor(0.0081, device='cuda:0', grad_fn=<AddBackward0>)
# 221 : tensor(0.0073, device='cuda:0', grad_fn=<AddBackward0>)
# 222 : tensor(0.0079, device='cuda:0', grad_fn=<AddBackward0>)
# 223 : tensor(0.0079, device='cuda:0', grad_fn=<AddBackward0>)
# 224 : tensor(0.0078, device='cuda:0', grad_fn=<AddBackward0>)
# 225 : tensor(0.0096, device='cuda:0', grad_fn=<AddBackward0>)
# 226 : tensor(0.0077, device='cuda:0', grad_fn=<AddBackward0>)
# 227 : tensor(0.0085, device='cuda:0', grad_fn=<AddBackward0>)
# 228 : tensor(0.0074, device='cuda:0', grad_fn=<AddBackward0>)
# 229 : tensor(0.0072, device='cuda:0', grad_fn=<AddBackward0>)
# 230 : tensor(0.0067, device='cuda:0', grad_fn=<AddBackward0>)
# 231 : tensor(0.0068, device='cuda:0', grad_fn=<AddBackward0>)
# 232 : tensor(0.0077, device='cuda:0', grad_fn=<AddBackward0>)
# 233 : tensor(0.0072, device='cuda:0', grad_fn=<AddBackward0>)
# 234 : tensor(0.0077, device='cuda:0', grad_fn=<AddBackward0>)
# 235 : tensor(0.0079, device='cuda:0', grad_fn=<AddBackward0>)
# 236 : tensor(0.0065, device='cuda:0', grad_fn=<AddBackward0>)
# 237 : tensor(0.0075, device='cuda:0', grad_fn=<AddBackward0>)
# 238 : tensor(0.0083, device='cuda:0', grad_fn=<AddBackward0>)
# 239 : tensor(0.0076, device='cuda:0', grad_fn=<AddBackward0>)
# 240 : tensor(0.0072, device='cuda:0', grad_fn=<AddBackward0>)
# 241 : tensor(0.0080, device='cuda:0', grad_fn=<AddBackward0>)
# 242 : tensor(0.0074, device='cuda:0', grad_fn=<AddBackward0>)
# 243 : tensor(0.0068, device='cuda:0', grad_fn=<AddBackward0>)
# 244 : tensor(0.0061, device='cuda:0', grad_fn=<AddBackward0>)
# 245 : tensor(0.0064, device='cuda:0', grad_fn=<AddBackward0>)
# 246 : tensor(0.0068, device='cuda:0', grad_fn=<AddBackward0>)
# 247 : tensor(0.0067, device='cuda:0', grad_fn=<AddBackward0>)
# 248 : tensor(0.0062, device='cuda:0', grad_fn=<AddBackward0>)
# 249 : tensor(0.0072, device='cuda:0', grad_fn=<AddBackward0>)
# 250 : tensor(0.0084, device='cuda:0', grad_fn=<AddBackward0>)
# 251 : tensor(0.0062, device='cuda:0', grad_fn=<AddBackward0>)
# 252 : tensor(0.0066, device='cuda:0', grad_fn=<AddBackward0>)
# 253 : tensor(0.0061, device='cuda:0', grad_fn=<AddBackward0>)
# 254 : tensor(0.0066, device='cuda:0', grad_fn=<AddBackward0>)
# 255 : tensor(0.0062, device='cuda:0', grad_fn=<AddBackward0>)
# 256 : tensor(0.0065, device='cuda:0', grad_fn=<AddBackward0>)
# 257 : tensor(0.0071, device='cuda:0', grad_fn=<AddBackward0>)
# 258 : tensor(0.0064, device='cuda:0', grad_fn=<AddBackward0>)
# 259 : tensor(0.0066, device='cuda:0', grad_fn=<AddBackward0>)
# 260 : tensor(0.0058, device='cuda:0', grad_fn=<AddBackward0>)
# 261 : tensor(0.0069, device='cuda:0', grad_fn=<AddBackward0>)
# 262 : tensor(0.0067, device='cuda:0', grad_fn=<AddBackward0>)
# 263 : tensor(0.0063, device='cuda:0', grad_fn=<AddBackward0>)
# 264 : tensor(0.0063, device='cuda:0', grad_fn=<AddBackward0>)
# 265 : tensor(0.0060, device='cuda:0', grad_fn=<AddBackward0>)
# 266 : tensor(0.0062, device='cuda:0', grad_fn=<AddBackward0>)
# 267 : tensor(0.0061, device='cuda:0', grad_fn=<AddBackward0>)
# 268 : tensor(0.0069, device='cuda:0', grad_fn=<AddBackward0>)
# 269 : tensor(0.0064, device='cuda:0', grad_fn=<AddBackward0>)
# 270 : tensor(0.0072, device='cuda:0', grad_fn=<AddBackward0>)
# 271 : tensor(0.0068, device='cuda:0', grad_fn=<AddBackward0>)
# 272 : tensor(0.0067, device='cuda:0', grad_fn=<AddBackward0>)
# 273 : tensor(0.0077, device='cuda:0', grad_fn=<AddBackward0>)
# 274 : tensor(0.0069, device='cuda:0', grad_fn=<AddBackward0>)
# 275 : tensor(0.0066, device='cuda:0', grad_fn=<AddBackward0>)
# 276 : tensor(0.0058, device='cuda:0', grad_fn=<AddBackward0>)
# 277 : tensor(0.0065, device='cuda:0', grad_fn=<AddBackward0>)
# 278 : tensor(0.0067, device='cuda:0', grad_fn=<AddBackward0>)
# 279 : tensor(0.0069, device='cuda:0', grad_fn=<AddBackward0>)
# 280 : tensor(0.0073, device='cuda:0', grad_fn=<AddBackward0>)
# 281 : tensor(0.0066, device='cuda:0', grad_fn=<AddBackward0>)
# 282 : tensor(0.0059, device='cuda:0', grad_fn=<AddBackward0>)
# 283 : tensor(0.0062, device='cuda:0', grad_fn=<AddBackward0>)
# 284 : tensor(0.0066, device='cuda:0', grad_fn=<AddBackward0>)
# 285 : tensor(0.0059, device='cuda:0', grad_fn=<AddBackward0>)
# 286 : tensor(0.0065, device='cuda:0', grad_fn=<AddBackward0>)
# 287 : tensor(0.0057, device='cuda:0', grad_fn=<AddBackward0>)
# 288 : tensor(0.0059, device='cuda:0', grad_fn=<AddBackward0>)
# 289 : tensor(0.0060, device='cuda:0', grad_fn=<AddBackward0>)
# 290 : tensor(0.0069, device='cuda:0', grad_fn=<AddBackward0>)
# 291 : tensor(0.0064, device='cuda:0', grad_fn=<AddBackward0>)
# 292 : tensor(0.0062, device='cuda:0', grad_fn=<AddBackward0>)
# 293 : tensor(0.0056, device='cuda:0', grad_fn=<AddBackward0>)
# 294 : tensor(0.0057, device='cuda:0', grad_fn=<AddBackward0>)
# 295 : tensor(0.0064, device='cuda:0', grad_fn=<AddBackward0>)
# 296 : tensor(0.0062, device='cuda:0', grad_fn=<AddBackward0>)
# 297 : tensor(0.0065, device='cuda:0', grad_fn=<AddBackward0>)
# 298 : tensor(0.0067, device='cuda:0', grad_fn=<AddBackward0>)
# 299 : tensor(0.0061, device='cuda:0', grad_fn=<AddBackward0>)
# 300 : tensor(0.0064, device='cuda:0', grad_fn=<AddBackward0>)
# Training epoch 300
# Error tensor(0.1635, device='cuda:0')
# 301 : tensor(0.0065, device='cuda:0', grad_fn=<AddBackward0>)
# 302 : tensor(0.0070, device='cuda:0', grad_fn=<AddBackward0>)
# 303 : tensor(0.0059, device='cuda:0', grad_fn=<AddBackward0>)
# 304 : tensor(0.0056, device='cuda:0', grad_fn=<AddBackward0>)
# 305 : tensor(0.0062, device='cuda:0', grad_fn=<AddBackward0>)
# 306 : tensor(0.0071, device='cuda:0', grad_fn=<AddBackward0>)
# 307 : tensor(0.0058, device='cuda:0', grad_fn=<AddBackward0>)
# 308 : tensor(0.0061, device='cuda:0', grad_fn=<AddBackward0>)
# 309 : tensor(0.0058, device='cuda:0', grad_fn=<AddBackward0>)
# 310 : tensor(0.0056, device='cuda:0', grad_fn=<AddBackward0>)
# 311 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 312 : tensor(0.0056, device='cuda:0', grad_fn=<AddBackward0>)
# 313 : tensor(0.0062, device='cuda:0', grad_fn=<AddBackward0>)
# 314 : tensor(0.0069, device='cuda:0', grad_fn=<AddBackward0>)
# 315 : tensor(0.0064, device='cuda:0', grad_fn=<AddBackward0>)
# 316 : tensor(0.0056, device='cuda:0', grad_fn=<AddBackward0>)
# 317 : tensor(0.0065, device='cuda:0', grad_fn=<AddBackward0>)
# 318 : tensor(0.0063, device='cuda:0', grad_fn=<AddBackward0>)
# 319 : tensor(0.0060, device='cuda:0', grad_fn=<AddBackward0>)
# 320 : tensor(0.0061, device='cuda:0', grad_fn=<AddBackward0>)
# 321 : tensor(0.0058, device='cuda:0', grad_fn=<AddBackward0>)
# 322 : tensor(0.0062, device='cuda:0', grad_fn=<AddBackward0>)
# 323 : tensor(0.0061, device='cuda:0', grad_fn=<AddBackward0>)
# 324 : tensor(0.0068, device='cuda:0', grad_fn=<AddBackward0>)
# 325 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 326 : tensor(0.0056, device='cuda:0', grad_fn=<AddBackward0>)
# 327 : tensor(0.0061, device='cuda:0', grad_fn=<AddBackward0>)
# 328 : tensor(0.0057, device='cuda:0', grad_fn=<AddBackward0>)
# 329 : tensor(0.0057, device='cuda:0', grad_fn=<AddBackward0>)
# 330 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 331 : tensor(0.0057, device='cuda:0', grad_fn=<AddBackward0>)
# 332 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 333 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 334 : tensor(0.0059, device='cuda:0', grad_fn=<AddBackward0>)
# 335 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 336 : tensor(0.0060, device='cuda:0', grad_fn=<AddBackward0>)
# 337 : tensor(0.0065, device='cuda:0', grad_fn=<AddBackward0>)
# 338 : tensor(0.0063, device='cuda:0', grad_fn=<AddBackward0>)
# 339 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 340 : tensor(0.0059, device='cuda:0', grad_fn=<AddBackward0>)
# 341 : tensor(0.0058, device='cuda:0', grad_fn=<AddBackward0>)
# 342 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 343 : tensor(0.0061, device='cuda:0', grad_fn=<AddBackward0>)
# 344 : tensor(0.0061, device='cuda:0', grad_fn=<AddBackward0>)
# 345 : tensor(0.0058, device='cuda:0', grad_fn=<AddBackward0>)
# 346 : tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# 347 : tensor(0.0066, device='cuda:0', grad_fn=<AddBackward0>)
# 348 : tensor(0.0064, device='cuda:0', grad_fn=<AddBackward0>)
# 349 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 350 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 351 : tensor(0.0059, device='cuda:0', grad_fn=<AddBackward0>)
# 352 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 353 : tensor(0.0060, device='cuda:0', grad_fn=<AddBackward0>)
# 354 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 355 : tensor(0.0065, device='cuda:0', grad_fn=<AddBackward0>)
# 356 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 357 : tensor(0.0058, device='cuda:0', grad_fn=<AddBackward0>)
# 358 : tensor(0.0060, device='cuda:0', grad_fn=<AddBackward0>)
# 359 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 360 : tensor(0.0064, device='cuda:0', grad_fn=<AddBackward0>)
# 361 : tensor(0.0048, device='cuda:0', grad_fn=<AddBackward0>)
# 362 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 363 : tensor(0.0067, device='cuda:0', grad_fn=<AddBackward0>)
# 364 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 365 : tensor(0.0060, device='cuda:0', grad_fn=<AddBackward0>)
# 366 : tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# 367 : tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# 368 : tensor(0.0060, device='cuda:0', grad_fn=<AddBackward0>)
# 369 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 370 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 371 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 372 : tensor(0.0058, device='cuda:0', grad_fn=<AddBackward0>)
# 373 : tensor(0.0056, device='cuda:0', grad_fn=<AddBackward0>)
# 374 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 375 : tensor(0.0056, device='cuda:0', grad_fn=<AddBackward0>)
# 376 : tensor(0.0049, device='cuda:0', grad_fn=<AddBackward0>)
# 377 : tensor(0.0050, device='cuda:0', grad_fn=<AddBackward0>)
# 378 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 379 : tensor(0.0058, device='cuda:0', grad_fn=<AddBackward0>)
# 380 : tensor(0.0057, device='cuda:0', grad_fn=<AddBackward0>)
# 381 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 382 : tensor(0.0049, device='cuda:0', grad_fn=<AddBackward0>)
# 383 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 384 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 385 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 386 : tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# 387 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 388 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 389 : tensor(0.0062, device='cuda:0', grad_fn=<AddBackward0>)
# 390 : tensor(0.0050, device='cuda:0', grad_fn=<AddBackward0>)
# 391 : tensor(0.0060, device='cuda:0', grad_fn=<AddBackward0>)
# 392 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 393 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 394 : tensor(0.0056, device='cuda:0', grad_fn=<AddBackward0>)
# 395 : tensor(0.0061, device='cuda:0', grad_fn=<AddBackward0>)
# 396 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 397 : tensor(0.0061, device='cuda:0', grad_fn=<AddBackward0>)
# 398 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 399 : tensor(0.0050, device='cuda:0', grad_fn=<AddBackward0>)
# 400 : tensor(0.0066, device='cuda:0', grad_fn=<AddBackward0>)
# Training epoch 400
# Error tensor(0.1485, device='cuda:0')
# 401 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 402 : tensor(0.0059, device='cuda:0', grad_fn=<AddBackward0>)
# 403 : tensor(0.0058, device='cuda:0', grad_fn=<AddBackward0>)
# 404 : tensor(0.0059, device='cuda:0', grad_fn=<AddBackward0>)
# 405 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 406 : tensor(0.0059, device='cuda:0', grad_fn=<AddBackward0>)
# 407 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 408 : tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# 409 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 410 : tensor(0.0049, device='cuda:0', grad_fn=<AddBackward0>)
# 411 : tensor(0.0057, device='cuda:0', grad_fn=<AddBackward0>)
# 412 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 413 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 414 : tensor(0.0061, device='cuda:0', grad_fn=<AddBackward0>)
# 415 : tensor(0.0049, device='cuda:0', grad_fn=<AddBackward0>)
# 416 : tensor(0.0049, device='cuda:0', grad_fn=<AddBackward0>)
# 417 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 418 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 419 : tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# 420 : tensor(0.0058, device='cuda:0', grad_fn=<AddBackward0>)
# 421 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 422 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 423 : tensor(0.0057, device='cuda:0', grad_fn=<AddBackward0>)
# 424 : tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# 425 : tensor(0.0060, device='cuda:0', grad_fn=<AddBackward0>)
# 426 : tensor(0.0049, device='cuda:0', grad_fn=<AddBackward0>)
# 427 : tensor(0.0048, device='cuda:0', grad_fn=<AddBackward0>)
# 428 : tensor(0.0056, device='cuda:0', grad_fn=<AddBackward0>)
# 429 : tensor(0.0048, device='cuda:0', grad_fn=<AddBackward0>)
# 430 : tensor(0.0057, device='cuda:0', grad_fn=<AddBackward0>)
# 431 : tensor(0.0047, device='cuda:0', grad_fn=<AddBackward0>)
# 432 : tensor(0.0049, device='cuda:0', grad_fn=<AddBackward0>)
# 433 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 434 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 435 : tensor(0.0061, device='cuda:0', grad_fn=<AddBackward0>)
# 436 : tensor(0.0049, device='cuda:0', grad_fn=<AddBackward0>)
# 437 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 438 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 439 : tensor(0.0057, device='cuda:0', grad_fn=<AddBackward0>)
# 440 : tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# 441 : tensor(0.0064, device='cuda:0', grad_fn=<AddBackward0>)
# 442 : tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# 443 : tensor(0.0059, device='cuda:0', grad_fn=<AddBackward0>)
# 444 : tensor(0.0049, device='cuda:0', grad_fn=<AddBackward0>)
# 445 : tensor(0.0046, device='cuda:0', grad_fn=<AddBackward0>)
# 446 : tensor(0.0048, device='cuda:0', grad_fn=<AddBackward0>)
# 447 : tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# 448 : tensor(0.0059, device='cuda:0', grad_fn=<AddBackward0>)
# 449 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 450 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 451 : tensor(0.0057, device='cuda:0', grad_fn=<AddBackward0>)
# 452 : tensor(0.0050, device='cuda:0', grad_fn=<AddBackward0>)
# 453 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 454 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 455 : tensor(0.0057, device='cuda:0', grad_fn=<AddBackward0>)
# 456 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 457 : tensor(0.0062, device='cuda:0', grad_fn=<AddBackward0>)
# 458 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 459 : tensor(0.0049, device='cuda:0', grad_fn=<AddBackward0>)
# 460 : tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# 461 : tensor(0.0047, device='cuda:0', grad_fn=<AddBackward0>)
# 462 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 463 : tensor(0.0056, device='cuda:0', grad_fn=<AddBackward0>)
# 464 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 465 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 466 : tensor(0.0046, device='cuda:0', grad_fn=<AddBackward0>)
# 467 : tensor(0.0050, device='cuda:0', grad_fn=<AddBackward0>)
# 468 : tensor(0.0060, device='cuda:0', grad_fn=<AddBackward0>)
# 469 : tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# 470 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 471 : tensor(0.0047, device='cuda:0', grad_fn=<AddBackward0>)
# 472 : tensor(0.0050, device='cuda:0', grad_fn=<AddBackward0>)
# 473 : tensor(0.0057, device='cuda:0', grad_fn=<AddBackward0>)
# 474 : tensor(0.0058, device='cuda:0', grad_fn=<AddBackward0>)
# 475 : tensor(0.0049, device='cuda:0', grad_fn=<AddBackward0>)
# 476 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 477 : tensor(0.0050, device='cuda:0', grad_fn=<AddBackward0>)
# 478 : tensor(0.0046, device='cuda:0', grad_fn=<AddBackward0>)
# 479 : tensor(0.0047, device='cuda:0', grad_fn=<AddBackward0>)
# 480 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 481 : tensor(0.0049, device='cuda:0', grad_fn=<AddBackward0>)
# 482 : tensor(0.0045, device='cuda:0', grad_fn=<AddBackward0>)
# 483 : tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# 484 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 485 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 486 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 487 : tensor(0.0049, device='cuda:0', grad_fn=<AddBackward0>)
# 488 : tensor(0.0050, device='cuda:0', grad_fn=<AddBackward0>)
# 489 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 490 : tensor(0.0041, device='cuda:0', grad_fn=<AddBackward0>)
# 491 : tensor(0.0042, device='cuda:0', grad_fn=<AddBackward0>)
# 492 : tensor(0.0050, device='cuda:0', grad_fn=<AddBackward0>)
# 493 : tensor(0.0047, device='cuda:0', grad_fn=<AddBackward0>)
# 494 : tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# 495 : tensor(0.0047, device='cuda:0', grad_fn=<AddBackward0>)
# 496 : tensor(0.0050, device='cuda:0', grad_fn=<AddBackward0>)
# 497 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 498 : tensor(0.0048, device='cuda:0', grad_fn=<AddBackward0>)
# 499 : tensor(0.0050, device='cuda:0', grad_fn=<AddBackward0>)
# 500 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# Training epoch 500
# Error tensor(0.1462, device='cuda:0')
# 501 : tensor(0.0045, device='cuda:0', grad_fn=<AddBackward0>)
# 502 : tensor(0.0043, device='cuda:0', grad_fn=<AddBackward0>)
# 503 : tensor(0.0045, device='cuda:0', grad_fn=<AddBackward0>)
# 504 : tensor(0.0049, device='cuda:0', grad_fn=<AddBackward0>)
# 505 : tensor(0.0046, device='cuda:0', grad_fn=<AddBackward0>)
# 506 : tensor(0.0045, device='cuda:0', grad_fn=<AddBackward0>)
# 507 : tensor(0.0047, device='cuda:0', grad_fn=<AddBackward0>)
# 508 : tensor(0.0050, device='cuda:0', grad_fn=<AddBackward0>)
# 509 : tensor(0.0046, device='cuda:0', grad_fn=<AddBackward0>)
# 510 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 511 : tensor(0.0061, device='cuda:0', grad_fn=<AddBackward0>)
# 512 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 513 : tensor(0.0045, device='cuda:0', grad_fn=<AddBackward0>)
# 514 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 515 : tensor(0.0047, device='cuda:0', grad_fn=<AddBackward0>)
# 516 : tensor(0.0045, device='cuda:0', grad_fn=<AddBackward0>)
# 517 : tensor(0.0047, device='cuda:0', grad_fn=<AddBackward0>)
# 518 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 519 : tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# 520 : tensor(0.0049, device='cuda:0', grad_fn=<AddBackward0>)
# 521 : tensor(0.0046, device='cuda:0', grad_fn=<AddBackward0>)
# 522 : tensor(0.0047, device='cuda:0', grad_fn=<AddBackward0>)
# 523 : tensor(0.0047, device='cuda:0', grad_fn=<AddBackward0>)
# 524 : tensor(0.0046, device='cuda:0', grad_fn=<AddBackward0>)
# 525 : tensor(0.0046, device='cuda:0', grad_fn=<AddBackward0>)
# 526 : tensor(0.0045, device='cuda:0', grad_fn=<AddBackward0>)
# 527 : tensor(0.0042, device='cuda:0', grad_fn=<AddBackward0>)
# 528 : tensor(0.0046, device='cuda:0', grad_fn=<AddBackward0>)
# 529 : tensor(0.0050, device='cuda:0', grad_fn=<AddBackward0>)
# 530 : tensor(0.0046, device='cuda:0', grad_fn=<AddBackward0>)
# 531 : tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# 532 : tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# 533 : tensor(0.0044, device='cuda:0', grad_fn=<AddBackward0>)
# 534 : tensor(0.0050, device='cuda:0', grad_fn=<AddBackward0>)
# 535 : tensor(0.0047, device='cuda:0', grad_fn=<AddBackward0>)
# 536 : tensor(0.0041, device='cuda:0', grad_fn=<AddBackward0>)
# 537 : tensor(0.0042, device='cuda:0', grad_fn=<AddBackward0>)
# 538 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 539 : tensor(0.0046, device='cuda:0', grad_fn=<AddBackward0>)
# 540 : tensor(0.0041, device='cuda:0', grad_fn=<AddBackward0>)
# 541 : tensor(0.0042, device='cuda:0', grad_fn=<AddBackward0>)
# 542 : tensor(0.0043, device='cuda:0', grad_fn=<AddBackward0>)
# 543 : tensor(0.0048, device='cuda:0', grad_fn=<AddBackward0>)
# 544 : tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# 545 : tensor(0.0041, device='cuda:0', grad_fn=<AddBackward0>)
# 546 : tensor(0.0045, device='cuda:0', grad_fn=<AddBackward0>)
# 547 : tensor(0.0045, device='cuda:0', grad_fn=<AddBackward0>)
# 548 : tensor(0.0048, device='cuda:0', grad_fn=<AddBackward0>)
# 549 : tensor(0.0047, device='cuda:0', grad_fn=<AddBackward0>)
# 550 : tensor(0.0048, device='cuda:0', grad_fn=<AddBackward0>)
# 551 : tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# 552 : tensor(0.0050, device='cuda:0', grad_fn=<AddBackward0>)
# 553 : tensor(0.0044, device='cuda:0', grad_fn=<AddBackward0>)
# 554 : tensor(0.0039, device='cuda:0', grad_fn=<AddBackward0>)
# 555 : tensor(0.0046, device='cuda:0', grad_fn=<AddBackward0>)
# 556 : tensor(0.0042, device='cuda:0', grad_fn=<AddBackward0>)
# 557 : tensor(0.0046, device='cuda:0', grad_fn=<AddBackward0>)
# 558 : tensor(0.0043, device='cuda:0', grad_fn=<AddBackward0>)
# 559 : tensor(0.0041, device='cuda:0', grad_fn=<AddBackward0>)
# 560 : tensor(0.0040, device='cuda:0', grad_fn=<AddBackward0>)
# 561 : tensor(0.0044, device='cuda:0', grad_fn=<AddBackward0>)
# 562 : tensor(0.0045, device='cuda:0', grad_fn=<AddBackward0>)
# 563 : tensor(0.0042, device='cuda:0', grad_fn=<AddBackward0>)
# 564 : tensor(0.0046, device='cuda:0', grad_fn=<AddBackward0>)
# 565 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 566 : tensor(0.0046, device='cuda:0', grad_fn=<AddBackward0>)
# 567 : tensor(0.0040, device='cuda:0', grad_fn=<AddBackward0>)
# 568 : tensor(0.0043, device='cuda:0', grad_fn=<AddBackward0>)
# 569 : tensor(0.0043, device='cuda:0', grad_fn=<AddBackward0>)
# 570 : tensor(0.0043, device='cuda:0', grad_fn=<AddBackward0>)
# 571 : tensor(0.0043, device='cuda:0', grad_fn=<AddBackward0>)
# 572 : tensor(0.0044, device='cuda:0', grad_fn=<AddBackward0>)
# 573 : tensor(0.0046, device='cuda:0', grad_fn=<AddBackward0>)
# 574 : tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# 575 : tensor(0.0049, device='cuda:0', grad_fn=<AddBackward0>)
# 576 : tensor(0.0042, device='cuda:0', grad_fn=<AddBackward0>)
# 577 : tensor(0.0045, device='cuda:0', grad_fn=<AddBackward0>)
# 578 : tensor(0.0039, device='cuda:0', grad_fn=<AddBackward0>)
# 579 : tensor(0.0050, device='cuda:0', grad_fn=<AddBackward0>)
# 580 : tensor(0.0048, device='cuda:0', grad_fn=<AddBackward0>)
# 581 : tensor(0.0043, device='cuda:0', grad_fn=<AddBackward0>)
# 582 : tensor(0.0047, device='cuda:0', grad_fn=<AddBackward0>)
# 583 : tensor(0.0041, device='cuda:0', grad_fn=<AddBackward0>)
# 584 : tensor(0.0046, device='cuda:0', grad_fn=<AddBackward0>)
# 585 : tensor(0.0041, device='cuda:0', grad_fn=<AddBackward0>)
# 586 : tensor(0.0040, device='cuda:0', grad_fn=<AddBackward0>)
# 587 : tensor(0.0046, device='cuda:0', grad_fn=<AddBackward0>)
# 588 : tensor(0.0045, device='cuda:0', grad_fn=<AddBackward0>)
# 589 : tensor(0.0041, device='cuda:0', grad_fn=<AddBackward0>)
# 590 : tensor(0.0042, device='cuda:0', grad_fn=<AddBackward0>)
# 591 : tensor(0.0046, device='cuda:0', grad_fn=<AddBackward0>)
# 592 : tensor(0.0043, device='cuda:0', grad_fn=<AddBackward0>)
# 593 : tensor(0.0042, device='cuda:0', grad_fn=<AddBackward0>)
# 594 : tensor(0.0040, device='cuda:0', grad_fn=<AddBackward0>)
# 595 : tensor(0.0041, device='cuda:0', grad_fn=<AddBackward0>)
# 596 : tensor(0.0040, device='cuda:0', grad_fn=<AddBackward0>)
# 597 : tensor(0.0041, device='cuda:0', grad_fn=<AddBackward0>)
# 598 : tensor(0.0040, device='cuda:0', grad_fn=<AddBackward0>)
# 599 : tensor(0.0046, device='cuda:0', grad_fn=<AddBackward0>)
# 600 : tensor(0.0047, device='cuda:0', grad_fn=<AddBackward0>)
# Training epoch 600
# Error tensor(0.1445, device='cuda:0')
# 601 : tensor(0.0041, device='cuda:0', grad_fn=<AddBackward0>)
# 602 : tensor(0.0042, device='cuda:0', grad_fn=<AddBackward0>)
# 603 : tensor(0.0042, device='cuda:0', grad_fn=<AddBackward0>)
# 604 : tensor(0.0039, device='cuda:0', grad_fn=<AddBackward0>)
# 605 : tensor(0.0038, device='cuda:0', grad_fn=<AddBackward0>)
# 606 : tensor(0.0046, device='cuda:0', grad_fn=<AddBackward0>)
# 607 : tensor(0.0045, device='cuda:0', grad_fn=<AddBackward0>)
# 608 : tensor(0.0041, device='cuda:0', grad_fn=<AddBackward0>)
# 609 : tensor(0.0041, device='cuda:0', grad_fn=<AddBackward0>)
# 610 : tensor(0.0047, device='cuda:0', grad_fn=<AddBackward0>)
# 611 : tensor(0.0040, device='cuda:0', grad_fn=<AddBackward0>)
# 612 : tensor(0.0043, device='cuda:0', grad_fn=<AddBackward0>)
# 613 : tensor(0.0037, device='cuda:0', grad_fn=<AddBackward0>)
# 614 : tensor(0.0045, device='cuda:0', grad_fn=<AddBackward0>)
# 615 : tensor(0.0038, device='cuda:0', grad_fn=<AddBackward0>)
# 616 : tensor(0.0046, device='cuda:0', grad_fn=<AddBackward0>)
# 617 : tensor(0.0042, device='cuda:0', grad_fn=<AddBackward0>)
# 618 : tensor(0.0040, device='cuda:0', grad_fn=<AddBackward0>)
# 619 : tensor(0.0048, device='cuda:0', grad_fn=<AddBackward0>)
# 620 : tensor(0.0040, device='cuda:0', grad_fn=<AddBackward0>)
# 621 : tensor(0.0042, device='cuda:0', grad_fn=<AddBackward0>)
# 622 : tensor(0.0038, device='cuda:0', grad_fn=<AddBackward0>)
# 623 : tensor(0.0041, device='cuda:0', grad_fn=<AddBackward0>)
# 624 : tensor(0.0048, device='cuda:0', grad_fn=<AddBackward0>)
# 625 : tensor(0.0047, device='cuda:0', grad_fn=<AddBackward0>)
# 626 : tensor(0.0041, device='cuda:0', grad_fn=<AddBackward0>)
# 627 : tensor(0.0043, device='cuda:0', grad_fn=<AddBackward0>)
# 628 : tensor(0.0043, device='cuda:0', grad_fn=<AddBackward0>)
# 629 : tensor(0.0044, device='cuda:0', grad_fn=<AddBackward0>)
# 630 : tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# 631 : tensor(0.0043, device='cuda:0', grad_fn=<AddBackward0>)
# 632 : tensor(0.0038, device='cuda:0', grad_fn=<AddBackward0>)
# 633 : tensor(0.0038, device='cuda:0', grad_fn=<AddBackward0>)
# 634 : tensor(0.0039, device='cuda:0', grad_fn=<AddBackward0>)
# 635 : tensor(0.0040, device='cuda:0', grad_fn=<AddBackward0>)
# 636 : tensor(0.0039, device='cuda:0', grad_fn=<AddBackward0>)
# 637 : tensor(0.0040, device='cuda:0', grad_fn=<AddBackward0>)
# 638 : tensor(0.0046, device='cuda:0', grad_fn=<AddBackward0>)
# 639 : tensor(0.0039, device='cuda:0', grad_fn=<AddBackward0>)
# 640 : tensor(0.0039, device='cuda:0', grad_fn=<AddBackward0>)
# 641 : tensor(0.0041, device='cuda:0', grad_fn=<AddBackward0>)
# 642 : tensor(0.0039, device='cuda:0', grad_fn=<AddBackward0>)
# 643 : tensor(0.0037, device='cuda:0', grad_fn=<AddBackward0>)
# 644 : tensor(0.0039, device='cuda:0', grad_fn=<AddBackward0>)
# 645 : tensor(0.0038, device='cuda:0', grad_fn=<AddBackward0>)
# 646 : tensor(0.0037, device='cuda:0', grad_fn=<AddBackward0>)
# 647 : tensor(0.0046, device='cuda:0', grad_fn=<AddBackward0>)
# 648 : tensor(0.0040, device='cuda:0', grad_fn=<AddBackward0>)
# 649 : tensor(0.0044, device='cuda:0', grad_fn=<AddBackward0>)
# 650 : tensor(0.0037, device='cuda:0', grad_fn=<AddBackward0>)
# 651 : tensor(0.0038, device='cuda:0', grad_fn=<AddBackward0>)
# 652 : tensor(0.0047, device='cuda:0', grad_fn=<AddBackward0>)
# 653 : tensor(0.0040, device='cuda:0', grad_fn=<AddBackward0>)
# 654 : tensor(0.0043, device='cuda:0', grad_fn=<AddBackward0>)
# 655 : tensor(0.0039, device='cuda:0', grad_fn=<AddBackward0>)
# 656 : tensor(0.0042, device='cuda:0', grad_fn=<AddBackward0>)
# 657 : tensor(0.0038, device='cuda:0', grad_fn=<AddBackward0>)
# 658 : tensor(0.0036, device='cuda:0', grad_fn=<AddBackward0>)
# 659 : tensor(0.0038, device='cuda:0', grad_fn=<AddBackward0>)
# 660 : tensor(0.0039, device='cuda:0', grad_fn=<AddBackward0>)
# 661 : tensor(0.0041, device='cuda:0', grad_fn=<AddBackward0>)
# 662 : tensor(0.0037, device='cuda:0', grad_fn=<AddBackward0>)
# 663 : tensor(0.0041, device='cuda:0', grad_fn=<AddBackward0>)
# 664 : tensor(0.0045, device='cuda:0', grad_fn=<AddBackward0>)
# 665 : tensor(0.0038, device='cuda:0', grad_fn=<AddBackward0>)
# 666 : tensor(0.0037, device='cuda:0', grad_fn=<AddBackward0>)
# 667 : tensor(0.0035, device='cuda:0', grad_fn=<AddBackward0>)
# 668 : tensor(0.0035, device='cuda:0', grad_fn=<AddBackward0>)
# 669 : tensor(0.0040, device='cuda:0', grad_fn=<AddBackward0>)
# 670 : tensor(0.0039, device='cuda:0', grad_fn=<AddBackward0>)
# 671 : tensor(0.0038, device='cuda:0', grad_fn=<AddBackward0>)
# 672 : tensor(0.0043, device='cuda:0', grad_fn=<AddBackward0>)
# 673 : tensor(0.0039, device='cuda:0', grad_fn=<AddBackward0>)
# 674 : tensor(0.0039, device='cuda:0', grad_fn=<AddBackward0>)
# 675 : tensor(0.0034, device='cuda:0', grad_fn=<AddBackward0>)
# 676 : tensor(0.0042, device='cuda:0', grad_fn=<AddBackward0>)
# 677 : tensor(0.0038, device='cuda:0', grad_fn=<AddBackward0>)
# 678 : tensor(0.0039, device='cuda:0', grad_fn=<AddBackward0>)
# 679 : tensor(0.0040, device='cuda:0', grad_fn=<AddBackward0>)
# 680 : tensor(0.0041, device='cuda:0', grad_fn=<AddBackward0>)
# 681 : tensor(0.0039, device='cuda:0', grad_fn=<AddBackward0>)
# 682 : tensor(0.0039, device='cuda:0', grad_fn=<AddBackward0>)
# 683 : tensor(0.0043, device='cuda:0', grad_fn=<AddBackward0>)
# 684 : tensor(0.0039, device='cuda:0', grad_fn=<AddBackward0>)
# 685 : tensor(0.0039, device='cuda:0', grad_fn=<AddBackward0>)
# 686 : tensor(0.0041, device='cuda:0', grad_fn=<AddBackward0>)
# 687 : tensor(0.0037, device='cuda:0', grad_fn=<AddBackward0>)
# 688 : tensor(0.0036, device='cuda:0', grad_fn=<AddBackward0>)
# 689 : tensor(0.0035, device='cuda:0', grad_fn=<AddBackward0>)
# 690 : tensor(0.0035, device='cuda:0', grad_fn=<AddBackward0>)
# 691 : tensor(0.0037, device='cuda:0', grad_fn=<AddBackward0>)
# 692 : tensor(0.0039, device='cuda:0', grad_fn=<AddBackward0>)
# 693 : tensor(0.0034, device='cuda:0', grad_fn=<AddBackward0>)
# 694 : tensor(0.0036, device='cuda:0', grad_fn=<AddBackward0>)
# 695 : tensor(0.0037, device='cuda:0', grad_fn=<AddBackward0>)
# 696 : tensor(0.0040, device='cuda:0', grad_fn=<AddBackward0>)
# 697 : tensor(0.0037, device='cuda:0', grad_fn=<AddBackward0>)
# 698 : tensor(0.0034, device='cuda:0', grad_fn=<AddBackward0>)
# 699 : tensor(0.0037, device='cuda:0', grad_fn=<AddBackward0>)
# 700 : tensor(0.0044, device='cuda:0', grad_fn=<AddBackward0>)
# Training epoch 700
# Error tensor(0.1386, device='cuda:0')
# 701 : tensor(0.0038, device='cuda:0', grad_fn=<AddBackward0>)
# 702 : tensor(0.0034, device='cuda:0', grad_fn=<AddBackward0>)
# 703 : tensor(0.0035, device='cuda:0', grad_fn=<AddBackward0>)
# 704 : tensor(0.0036, device='cuda:0', grad_fn=<AddBackward0>)
# 705 : tensor(0.0035, device='cuda:0', grad_fn=<AddBackward0>)
# 706 : tensor(0.0034, device='cuda:0', grad_fn=<AddBackward0>)
# 707 : tensor(0.0035, device='cuda:0', grad_fn=<AddBackward0>)
# 708 : tensor(0.0035, device='cuda:0', grad_fn=<AddBackward0>)
# 709 : tensor(0.0034, device='cuda:0', grad_fn=<AddBackward0>)
# 710 : tensor(0.0035, device='cuda:0', grad_fn=<AddBackward0>)
# 711 : tensor(0.0036, device='cuda:0', grad_fn=<AddBackward0>)
# 712 : tensor(0.0033, device='cuda:0', grad_fn=<AddBackward0>)
# 713 : tensor(0.0041, device='cuda:0', grad_fn=<AddBackward0>)
# 714 : tensor(0.0039, device='cuda:0', grad_fn=<AddBackward0>)
# 715 : tensor(0.0036, device='cuda:0', grad_fn=<AddBackward0>)
# 716 : tensor(0.0035, device='cuda:0', grad_fn=<AddBackward0>)
# 717 : tensor(0.0037, device='cuda:0', grad_fn=<AddBackward0>)
# 718 : tensor(0.0035, device='cuda:0', grad_fn=<AddBackward0>)
# 719 : tensor(0.0033, device='cuda:0', grad_fn=<AddBackward0>)
# 720 : tensor(0.0034, device='cuda:0', grad_fn=<AddBackward0>)
# 721 : tensor(0.0033, device='cuda:0', grad_fn=<AddBackward0>)
# 722 : tensor(0.0033, device='cuda:0', grad_fn=<AddBackward0>)
# 723 : tensor(0.0046, device='cuda:0', grad_fn=<AddBackward0>)
# 724 : tensor(0.0036, device='cuda:0', grad_fn=<AddBackward0>)
# 725 : tensor(0.0038, device='cuda:0', grad_fn=<AddBackward0>)
# 726 : tensor(0.0039, device='cuda:0', grad_fn=<AddBackward0>)
# 727 : tensor(0.0034, device='cuda:0', grad_fn=<AddBackward0>)
# 728 : tensor(0.0040, device='cuda:0', grad_fn=<AddBackward0>)
# 729 : tensor(0.0033, device='cuda:0', grad_fn=<AddBackward0>)
# 730 : tensor(0.0038, device='cuda:0', grad_fn=<AddBackward0>)
# 731 : tensor(0.0038, device='cuda:0', grad_fn=<AddBackward0>)
# 732 : tensor(0.0035, device='cuda:0', grad_fn=<AddBackward0>)
# 733 : tensor(0.0034, device='cuda:0', grad_fn=<AddBackward0>)
# 734 : tensor(0.0031, device='cuda:0', grad_fn=<AddBackward0>)
# 735 : tensor(0.0037, device='cuda:0', grad_fn=<AddBackward0>)
# 736 : tensor(0.0035, device='cuda:0', grad_fn=<AddBackward0>)
# 737 : tensor(0.0039, device='cuda:0', grad_fn=<AddBackward0>)
# 738 : tensor(0.0034, device='cuda:0', grad_fn=<AddBackward0>)
# 739 : tensor(0.0034, device='cuda:0', grad_fn=<AddBackward0>)
# 740 : tensor(0.0032, device='cuda:0', grad_fn=<AddBackward0>)
# 741 : tensor(0.0033, device='cuda:0', grad_fn=<AddBackward0>)
# 742 : tensor(0.0033, device='cuda:0', grad_fn=<AddBackward0>)
# 743 : tensor(0.0034, device='cuda:0', grad_fn=<AddBackward0>)
# 744 : tensor(0.0037, device='cuda:0', grad_fn=<AddBackward0>)
# 745 : tensor(0.0036, device='cuda:0', grad_fn=<AddBackward0>)
# 746 : tensor(0.0032, device='cuda:0', grad_fn=<AddBackward0>)
# 747 : tensor(0.0034, device='cuda:0', grad_fn=<AddBackward0>)
# 748 : tensor(0.0034, device='cuda:0', grad_fn=<AddBackward0>)
# 749 : tensor(0.0033, device='cuda:0', grad_fn=<AddBackward0>)
# 750 : tensor(0.0036, device='cuda:0', grad_fn=<AddBackward0>)
# 751 : tensor(0.0035, device='cuda:0', grad_fn=<AddBackward0>)
# 752 : tensor(0.0034, device='cuda:0', grad_fn=<AddBackward0>)
# 753 : tensor(0.0033, device='cuda:0', grad_fn=<AddBackward0>)
# 754 : tensor(0.0037, device='cuda:0', grad_fn=<AddBackward0>)
# 755 : tensor(0.0032, device='cuda:0', grad_fn=<AddBackward0>)
# 756 : tensor(0.0036, device='cuda:0', grad_fn=<AddBackward0>)
# 757 : tensor(0.0033, device='cuda:0', grad_fn=<AddBackward0>)
# 758 : tensor(0.0032, device='cuda:0', grad_fn=<AddBackward0>)
# 759 : tensor(0.0039, device='cuda:0', grad_fn=<AddBackward0>)
# 760 : tensor(0.0039, device='cuda:0', grad_fn=<AddBackward0>)
# 761 : tensor(0.0038, device='cuda:0', grad_fn=<AddBackward0>)
# 762 : tensor(0.0033, device='cuda:0', grad_fn=<AddBackward0>)
# 763 : tensor(0.0040, device='cuda:0', grad_fn=<AddBackward0>)
# 764 : tensor(0.0035, device='cuda:0', grad_fn=<AddBackward0>)
# 765 : tensor(0.0037, device='cuda:0', grad_fn=<AddBackward0>)
# 766 : tensor(0.0036, device='cuda:0', grad_fn=<AddBackward0>)
# 767 : tensor(0.0034, device='cuda:0', grad_fn=<AddBackward0>)
# 768 : tensor(0.0035, device='cuda:0', grad_fn=<AddBackward0>)
# 769 : tensor(0.0038, device='cuda:0', grad_fn=<AddBackward0>)
# ...
# 950 : tensor(0.0031, device='cuda:0', grad_fn=<AddBackward0>)
# 951 : tensor(0.0030, device='cuda:0', grad_fn=<AddBackward0>)
# 952 : tensor(0.0028, device='cuda:0', grad_fn=<AddBackward0>)
# 953 : tensor(0.0031, device='cuda:0', grad_fn=<AddBackward0>)
# 954 : tensor(0.0031, device='cuda:0', grad_fn=<AddBackward0>)
# 955 : tensor(0.0031, device='cuda:0', grad_fn=<AddBackward0>)
# 956 : tensor(0.0032, device='cuda:0', grad_fn=<AddBackward0>)
# 957 : tensor(0.0029, device='cuda:0', grad_fn=<AddBackward0>)
# 958 : tensor(0.0039, device='cuda:0', grad_fn=<AddBackward0>)
# 959 : tensor(0.0038, device='cuda:0', grad_fn=<AddBackward0>)
# 960 : tensor(0.0034, device='cuda:0', grad_fn=<AddBackward0>)
# 961 : tensor(0.0029, device='cuda:0', grad_fn=<AddBackward0>)
# 962 : tensor(0.0030, device='cuda:0', grad_fn=<AddBackward0>)
# 963 : tensor(0.0031, device='cuda:0', grad_fn=<AddBackward0>)
# 964 : tensor(0.0032, device='cuda:0', grad_fn=<AddBackward0>)
# 965 : tensor(0.0028, device='cuda:0', grad_fn=<AddBackward0>)
# 966 : tensor(0.0027, device='cuda:0', grad_fn=<AddBackward0>)
# 967 : tensor(0.0036, device='cuda:0', grad_fn=<AddBackward0>)
# 968 : tensor(0.0032, device='cuda:0', grad_fn=<AddBackward0>)
# 969 : tensor(0.0028, device='cuda:0', grad_fn=<AddBackward0>)
# 970 : tensor(0.0032, device='cuda:0', grad_fn=<AddBackward0>)
# 971 : tensor(0.0027, device='cuda:0', grad_fn=<AddBackward0>)
# 972 : tensor(0.0029, device='cuda:0', grad_fn=<AddBackward0>)
# 973 : tensor(0.0031, device='cuda:0', grad_fn=<AddBackward0>)
# 974 : tensor(0.0029, device='cuda:0', grad_fn=<AddBackward0>)
# 975 : tensor(0.0030, device='cuda:0', grad_fn=<AddBackward0>)
# 976 : tensor(0.0031, device='cuda:0', grad_fn=<AddBackward0>)
# 977 : tensor(0.0030, device='cuda:0', grad_fn=<AddBackward0>)
# 978 : tensor(0.0030, device='cuda:0', grad_fn=<AddBackward0>)
# 979 : tensor(0.0033, device='cuda:0', grad_fn=<AddBackward0>)
# 980 : tensor(0.0028, device='cuda:0', grad_fn=<AddBackward0>)
# 981 : tensor(0.0029, device='cuda:0', grad_fn=<AddBackward0>)
# 982 : tensor(0.0028, device='cuda:0', grad_fn=<AddBackward0>)
# 983 : tensor(0.0032, device='cuda:0', grad_fn=<AddBackward0>)
# 984 : tensor(0.0027, device='cuda:0', grad_fn=<AddBackward0>)
# 985 : tensor(0.0030, device='cuda:0', grad_fn=<AddBackward0>)
# 986 : tensor(0.0028, device='cuda:0', grad_fn=<AddBackward0>)
# 987 : tensor(0.0028, device='cuda:0', grad_fn=<AddBackward0>)
# 988 : tensor(0.0031, device='cuda:0', grad_fn=<AddBackward0>)
# 989 : tensor(0.0028, device='cuda:0', grad_fn=<AddBackward0>)
# 990 : tensor(0.0030, device='cuda:0', grad_fn=<AddBackward0>)
# 991 : tensor(0.0030, device='cuda:0', grad_fn=<AddBackward0>)
# 992 : tensor(0.0027, device='cuda:0', grad_fn=<AddBackward0>)
# 993 : tensor(0.0030, device='cuda:0', grad_fn=<AddBackward0>)
# 994 : tensor(0.0029, device='cuda:0', grad_fn=<AddBackward0>)
# 995 : tensor(0.0028, device='cuda:0', grad_fn=<AddBackward0>)
# 996 : tensor(0.0029, device='cuda:0', grad_fn=<AddBackward0>)
# 997 : tensor(0.0030, device='cuda:0', grad_fn=<AddBackward0>)
# 998 : tensor(0.0035, device='cuda:0', grad_fn=<AddBackward0>)
# 999 : tensor(0.0028, device='cuda:0', grad_fn=<AddBackward0>)
# 1000 : tensor(0.0029, device='cuda:0', grad_fn=<AddBackward0>)
# Training epoch 1000
# Error tensor(0.1493, device='cuda:0')
# 398 : tensor(0.0102, device='cuda:0', grad_fn=<AddBackward0>)
# 399 : tensor(0.0102, device='cuda:0', grad_fn=<AddBackward0>)
# 400 : tensor(0.0101, device='cuda:0', grad_fn=<AddBackward0>)
# Training epoch 400
# Error tensor(0.2479, device='cuda:0')
# 401 : tensor(0.0107, device='cuda:0', grad_fn=<AddBackward0>)
# 402 : tensor(0.0108, device='cuda:0', grad_fn=<AddBackward0>)
# 403 : tensor(0.0110, device='cuda:0', grad_fn=<AddBackward0>)
# 404 : tensor(0.0107, device='cuda:0', grad_fn=<AddBackward0>)
# 405 : tensor(0.0106, device='cuda:0', grad_fn=<AddBackward0>)
# 406 : tensor(0.0104, device='cuda:0', grad_fn=<AddBackward0>)
# 407 : tensor(0.0105, device='cuda:0', grad_fn=<AddBackward0>)
# 408 : tensor(0.0108, device='cuda:0', grad_fn=<AddBackward0>)
# 409 : tensor(0.0108, device='cuda:0', grad_fn=<AddBackward0>)
# 410 : tensor(0.0109, device='cuda:0', grad_fn=<AddBackward0>)
# 411 : tensor(0.0106, device='cuda:0', grad_fn=<AddBackward0>)
# 412 : tensor(0.0106, device='cuda:0', grad_fn=<AddBackward0>)
# 413 : tensor(0.0104, device='cuda:0', grad_fn=<AddBackward0>)
# 414 : tensor(0.0106, device='cuda:0', grad_fn=<AddBackward0>)
# 415 : tensor(0.0105, device='cuda:0', grad_fn=<AddBackward0>)
# 416 : tensor(0.0105, device='cuda:0', grad_fn=<AddBackward0>)
# 417 : tensor(0.0105, device='cuda:0', grad_fn=<AddBackward0>)
# 418 : tensor(0.0105, device='cuda:0', grad_fn=<AddBackward0>)
# 419 : tensor(0.0107, device='cuda:0', grad_fn=<AddBackward0>)
# 420 : tensor(0.0108, device='cuda:0', grad_fn=<AddBackward0>)
# 421 : tensor(0.0105, device='cuda:0', grad_fn=<AddBackward0>)
# 422 : tensor(0.0105, device='cuda:0', grad_fn=<AddBackward0>)
# 423 : tensor(0.0106, device='cuda:0', grad_fn=<AddBackward0>)
# 424 : tensor(0.0107, device='cuda:0', grad_fn=<AddBackward0>)
# 425 : tensor(0.0106, device='cuda:0', grad_fn=<AddBackward0>)
# 426 : tensor(0.0105, device='cuda:0', grad_fn=<AddBackward0>)
# 427 : tensor(0.0107, device='cuda:0', grad_fn=<AddBackward0>)
# 428 : tensor(0.0102, device='cuda:0', grad_fn=<AddBackward0>)
# 429 : tensor(0.0103, device='cuda:0', grad_fn=<AddBackward0>)
# 430 : tensor(0.0104, device='cuda:0', grad_fn=<AddBackward0>)
# 431 : tensor(0.0105, device='cuda:0', grad_fn=<AddBackward0>)
# 432 : tensor(0.0105, device='cuda:0', grad_fn=<AddBackward0>)
# 433 : tensor(0.0104, device='cuda:0', grad_fn=<AddBackward0>)
# 434 : tensor(0.0102, device='cuda:0', grad_fn=<AddBackward0>)
# 435 : tensor(0.0105, device='cuda:0', grad_fn=<AddBackward0>)
# 436 : tensor(0.0104, device='cuda:0', grad_fn=<AddBackward0>)
# 437 : tensor(0.0105, device='cuda:0', grad_fn=<AddBackward0>)
# 438 : tensor(0.0103, device='cuda:0', grad_fn=<AddBackward0>)
# 439 : tensor(0.0107, device='cuda:0', grad_fn=<AddBackward0>)
# 440 : tensor(0.0103, device='cuda:0', grad_fn=<AddBackward0>)
# 441 : tensor(0.0104, device='cuda:0', grad_fn=<AddBackward0>)
# 442 : tensor(0.0105, device='cuda:0', grad_fn=<AddBackward0>)
# 443 : tensor(0.0105, device='cuda:0', grad_fn=<AddBackward0>)
# 444 : tensor(0.0105, device='cuda:0', grad_fn=<AddBackward0>)
# 445 : tensor(0.0107, device='cuda:0', grad_fn=<AddBackward0>)
# 446 : tensor(0.0105, device='cuda:0', grad_fn=<AddBackward0>)
# 447 : tensor(0.0106, device='cuda:0', grad_fn=<AddBackward0>)
# 448 : tensor(0.0102, device='cuda:0', grad_fn=<AddBackward0>)
# 449 : tensor(0.0101, device='cuda:0', grad_fn=<AddBackward0>)
# 450 : tensor(0.0104, device='cuda:0', grad_fn=<AddBackward0>)
# 451 : tensor(0.0105, device='cuda:0', grad_fn=<AddBackward0>)
# 452 : tensor(0.0104, device='cuda:0', grad_fn=<AddBackward0>)
# 453 : tensor(0.0103, device='cuda:0', grad_fn=<AddBackward0>)
# 454 : tensor(0.0104, device='cuda:0', grad_fn=<AddBackward0>)
# 455 : tensor(0.0104, device='cuda:0', grad_fn=<AddBackward0>)
# 456 : tensor(0.0103, device='cuda:0', grad_fn=<AddBackward0>)
# 457 : tensor(0.0100, device='cuda:0', grad_fn=<AddBackward0>)
# 458 : tensor(0.0103, device='cuda:0', grad_fn=<AddBackward0>)
# 459 : tensor(0.0103, device='cuda:0', grad_fn=<AddBackward0>)
# 460 : tensor(0.0103, device='cuda:0', grad_fn=<AddBackward0>)
# 461 : tensor(0.0101, device='cuda:0', grad_fn=<AddBackward0>)
# 462 : tensor(0.0101, device='cuda:0', grad_fn=<AddBackward0>)
# 463 : tensor(0.0105, device='cuda:0', grad_fn=<AddBackward0>)
# 464 : tensor(0.0102, device='cuda:0', grad_fn=<AddBackward0>)
# 465 : tensor(0.0102, device='cuda:0', grad_fn=<AddBackward0>)
# 466 : tensor(0.0103, device='cuda:0', grad_fn=<AddBackward0>)
# 467 : tensor(0.0105, device='cuda:0', grad_fn=<AddBackward0>)
# 468 : tensor(0.0105, device='cuda:0', grad_fn=<AddBackward0>)
# 469 : tensor(0.0102, device='cuda:0', grad_fn=<AddBackward0>)
# 470 : tensor(0.0103, device='cuda:0', grad_fn=<AddBackward0>)
# 471 : tensor(0.0104, device='cuda:0', grad_fn=<AddBackward0>)
# 472 : tensor(0.0102, device='cuda:0', grad_fn=<AddBackward0>)
# 473 : tensor(0.0103, device='cuda:0', grad_fn=<AddBackward0>)
# 474 : tensor(0.0103, device='cuda:0', grad_fn=<AddBackward0>)
# 475 : tensor(0.0103, device='cuda:0', grad_fn=<AddBackward0>)
# 476 : tensor(0.0104, device='cuda:0', grad_fn=<AddBackward0>)
# 477 : tensor(0.0101, device='cuda:0', grad_fn=<AddBackward0>)
# 478 : tensor(0.0103, device='cuda:0', grad_fn=<AddBackward0>)
# 479 : tensor(0.0103, device='cuda:0', grad_fn=<AddBackward0>)
# 480 : tensor(0.0101, device='cuda:0', grad_fn=<AddBackward0>)
# 481 : tensor(0.0103, device='cuda:0', grad_fn=<AddBackward0>)
# 482 : tensor(0.0102, device='cuda:0', grad_fn=<AddBackward0>)
# 483 : tensor(0.0106, device='cuda:0', grad_fn=<AddBackward0>)
# 484 : tensor(0.0105, device='cuda:0', grad_fn=<AddBackward0>)
# 485 : tensor(0.0102, device='cuda:0', grad_fn=<AddBackward0>)
# 486 : tensor(0.0101, device='cuda:0', grad_fn=<AddBackward0>)
# 487 : tensor(0.0101, device='cuda:0', grad_fn=<AddBackward0>)
# 488 : tensor(0.0103, device='cuda:0', grad_fn=<AddBackward0>)
# 489 : tensor(0.0103, device='cuda:0', grad_fn=<AddBackward0>)
# 490 : tensor(0.0106, device='cuda:0', grad_fn=<AddBackward0>)
# 491 : tensor(0.0104, device='cuda:0', grad_fn=<AddBackward0>)
# 492 : tensor(0.0104, device='cuda:0', grad_fn=<AddBackward0>)
# 493 : tensor(0.0104, device='cuda:0', grad_fn=<AddBackward0>)
# 494 : tensor(0.0099, device='cuda:0', grad_fn=<AddBackward0>)
# 495 : tensor(0.0100, device='cuda:0', grad_fn=<AddBackward0>)
# 496 : tensor(0.0101, device='cuda:0', grad_fn=<AddBackward0>)
# 497 : tensor(0.0103, device='cuda:0', grad_fn=<AddBackward0>)
# 498 : tensor(0.0102, device='cuda:0', grad_fn=<AddBackward0>)
# 499 : tensor(0.0107, device='cuda:0', grad_fn=<AddBackward0>)
# 500 : tensor(0.0102, device='cuda:0', grad_fn=<AddBackward0>)
# Training epoch 500
# Error tensor(0.2311, device='cuda:0')
# 501 : tensor(0.0109, device='cuda:0', grad_fn=<AddBackward0>)
# 502 : tensor(0.0104, device='cuda:0', grad_fn=<AddBackward0>)
# 503 : tensor(0.0104, device='cuda:0', grad_fn=<AddBackward0>)
# 504 : tensor(0.0103, device='cuda:0', grad_fn=<AddBackward0>)
# 505 : tensor(0.0107, device='cuda:0', grad_fn=<AddBackward0>)
# 506 : tensor(0.0104, device='cuda:0', grad_fn=<AddBackward0>)
# 507 : tensor(0.0105, device='cuda:0', grad_fn=<AddBackward0>)
# 508 : tensor(0.0103, device='cuda:0', grad_fn=<AddBackward0>)
# 509 : tensor(0.0101, device='cuda:0', grad_fn=<AddBackward0>)
# 510 : tensor(0.0102, device='cuda:0', grad_fn=<AddBackward0>)
# 511 : tensor(0.0105, device='cuda:0', grad_fn=<AddBackward0>)
# 512 : tensor(0.0100, device='cuda:0', grad_fn=<AddBackward0>)
# 513 : tensor(0.0099, device='cuda:0', grad_fn=<AddBackward0>)
# 514 : tensor(0.0101, device='cuda:0', grad_fn=<AddBackward0>)
# 515 : tensor(0.0106, device='cuda:0', grad_fn=<AddBackward0>)
# 516 : tensor(0.0105, device='cuda:0', grad_fn=<AddBackward0>)
# 517 : tensor(0.0104, device='cuda:0', grad_fn=<AddBackward0>)
# 518 : tensor(0.0101, device='cuda:0', grad_fn=<AddBackward0>)
# 519 : tensor(0.0101, device='cuda:0', grad_fn=<AddBackward0>)
# 520 : tensor(0.0102, device='cuda:0', grad_fn=<AddBackward0>)
# 521 : tensor(0.0105, device='cuda:0', grad_fn=<AddBackward0>)
# 522 : tensor(0.0102, device='cuda:0', grad_fn=<AddBackward0>)
# 523 : tensor(0.0105, device='cuda:0', grad_fn=<AddBackward0>)
# 524 : tensor(0.0102, device='cuda:0', grad_fn=<AddBackward0>)
# 525 : tensor(0.0100, device='cuda:0', grad_fn=<AddBackward0>)
# 526 : tensor(0.0102, device='cuda:0', grad_fn=<AddBackward0>)
# 527 : tensor(0.0099, device='cuda:0', grad_fn=<AddBackward0>)
# 528 : tensor(0.0100, device='cuda:0', grad_fn=<AddBackward0>)
# 529 : tensor(0.0104, device='cuda:0', grad_fn=<AddBackward0>)
# 530 : tensor(0.0102, device='cuda:0', grad_fn=<AddBackward0>)
# 531 : tensor(0.0100, device='cuda:0', grad_fn=<AddBackward0>)
# 532 : tensor(0.0099, device='cuda:0', grad_fn=<AddBackward0>)
# 533 : tensor(0.0099, device='cuda:0', grad_fn=<AddBackward0>)
# 534 : tensor(0.0098, device='cuda:0', grad_fn=<AddBackward0>)
# 535 : tensor(0.0107, device='cuda:0', grad_fn=<AddBackward0>)
# 536 : tensor(0.0104, device='cuda:0', grad_fn=<AddBackward0>)
# 537 : tensor(0.0104, device='cuda:0', grad_fn=<AddBackward0>)
# 538 : tensor(0.0099, device='cuda:0', grad_fn=<AddBackward0>)
# 539 : tensor(0.0098, device='cuda:0', grad_fn=<AddBackward0>)
# 540 : tensor(0.0105, device='cuda:0', grad_fn=<AddBackward0>)
# 541 : tensor(0.0103, device='cuda:0', grad_fn=<AddBackward0>)
# 542 : tensor(0.0101, device='cuda:0', grad_fn=<AddBackward0>)
# 543 : tensor(0.0102, device='cuda:0', grad_fn=<AddBackward0>)
# 544 : tensor(0.0100, device='cuda:0', grad_fn=<AddBackward0>)
# 545 : tensor(0.0102, device='cuda:0', grad_fn=<AddBackward0>)
# 546 : tensor(0.0099, device='cuda:0', grad_fn=<AddBackward0>)
# 547 : tensor(0.0100, device='cuda:0', grad_fn=<AddBackward0>)
# 548 : tensor(0.0098, device='cuda:0', grad_fn=<AddBackward0>)
# 549 : tensor(0.0100, device='cuda:0', grad_fn=<AddBackward0>)
# 550 : tensor(0.0096, device='cuda:0', grad_fn=<AddBackward0>)
# 551 : tensor(0.0100, device='cuda:0', grad_fn=<AddBackward0>)
# 552 : tensor(0.0099, device='cuda:0', grad_fn=<AddBackward0>)
# 553 : tensor(0.0098, device='cuda:0', grad_fn=<AddBackward0>)
# 554 : tensor(0.0102, device='cuda:0', grad_fn=<AddBackward0>)
# 555 : tensor(0.0099, device='cuda:0', grad_fn=<AddBackward0>)
# 556 : tensor(0.0096, device='cuda:0', grad_fn=<AddBackward0>)
# 557 : tensor(0.0100, device='cuda:0', grad_fn=<AddBackward0>)
# 558 : tensor(0.0099, device='cuda:0', grad_fn=<AddBackward0>)
# 559 : tensor(0.0096, device='cuda:0', grad_fn=<AddBackward0>)
# 560 : tensor(0.0101, device='cuda:0', grad_fn=<AddBackward0>)
# 561 : tensor(0.0100, device='cuda:0', grad_fn=<AddBackward0>)
# 562 : tensor(0.0100, device='cuda:0', grad_fn=<AddBackward0>)
# 563 : tensor(0.0097, device='cuda:0', grad_fn=<AddBackward0>)
# 564 : tensor(0.0100, device='cuda:0', grad_fn=<AddBackward0>)
# 565 : tensor(0.0099, device='cuda:0', grad_fn=<AddBackward0>)
# 566 : tensor(0.0097, device='cuda:0', grad_fn=<AddBackward0>)
# 567 : tensor(0.0098, device='cuda:0', grad_fn=<AddBackward0>)
# 568 : tensor(0.0098, device='cuda:0', grad_fn=<AddBackward0>)
# 569 : tensor(0.0098, device='cuda:0', grad_fn=<AddBackward0>)
# 570 : tensor(0.0097, device='cuda:0', grad_fn=<AddBackward0>)
# 571 : tensor(0.0099, device='cuda:0', grad_fn=<AddBackward0>)
# 572 : tensor(0.0099, device='cuda:0', grad_fn=<AddBackward0>)
# 573 : tensor(0.0095, device='cuda:0', grad_fn=<AddBackward0>)
# 574 : tensor(0.0098, device='cuda:0', grad_fn=<AddBackward0>)
# 575 : tensor(0.0102, device='cuda:0', grad_fn=<AddBackward0>)
# 576 : tensor(0.0097, device='cuda:0', grad_fn=<AddBackward0>)
# 577 : tensor(0.0099, device='cuda:0', grad_fn=<AddBackward0>)
# 578 : tensor(0.0095, device='cuda:0', grad_fn=<AddBackward0>)
# 579 : tensor(0.0095, device='cuda:0', grad_fn=<AddBackward0>)
# 580 : tensor(0.0098, device='cuda:0', grad_fn=<AddBackward0>)
# 581 : tensor(0.0098, device='cuda:0', grad_fn=<AddBackward0>)
# 582 : tensor(0.0095, device='cuda:0', grad_fn=<AddBackward0>)
# 583 : tensor(0.0099, device='cuda:0', grad_fn=<AddBackward0>)
# 584 : tensor(0.0098, device='cuda:0', grad_fn=<AddBackward0>)
# 585 : tensor(0.0097, device='cuda:0', grad_fn=<AddBackward0>)
# 586 : tensor(0.0096, device='cuda:0', grad_fn=<AddBackward0>)
# 587 : tensor(0.0098, device='cuda:0', grad_fn=<AddBackward0>)
# 588 : tensor(0.0103, device='cuda:0', grad_fn=<AddBackward0>)
# 589 : tensor(0.0097, device='cuda:0', grad_fn=<AddBackward0>)
# 590 : tensor(0.0095, device='cuda:0', grad_fn=<AddBackward0>)
# 591 : tensor(0.0096, device='cuda:0', grad_fn=<AddBackward0>)
# 592 : tensor(0.0095, device='cuda:0', grad_fn=<AddBackward0>)
# 593 : tensor(0.0096, device='cuda:0', grad_fn=<AddBackward0>)
# 594 : tensor(0.0096, device='cuda:0', grad_fn=<AddBackward0>)
# 595 : tensor(0.0098, device='cuda:0', grad_fn=<AddBackward0>)
# 596 : tensor(0.0095, device='cuda:0', grad_fn=<AddBackward0>)
# 597 : tensor(0.0100, device='cuda:0', grad_fn=<AddBackward0>)
# 598 : tensor(0.0097, device='cuda:0', grad_fn=<AddBackward0>)
# 599 : tensor(0.0093, device='cuda:0', grad_fn=<AddBackward0>)
# 600 : tensor(0.0096, device='cuda:0', grad_fn=<AddBackward0>)
# Training epoch 600
# Error tensor(0.2446, device='cuda:0')

# %%
# Rate of sparsity
torch.mean(shred.e_sindy.coefficient_mask*1.0)
# Out:
# tensor(0.4117, device='cuda:0')

# %%
#We then generate reconstructions from the test set and print mean square error compared to the ground truth.
test_recons = sc.inverse_transform(shred(test_dataset.X).detach().cpu().numpy())
test_ground_truth = sc.inverse_transform(test_dataset.Y.detach().cpu().numpy())
print(np.linalg.norm(test_recons - test_ground_truth) / np.linalg.norm(test_ground_truth))
# Out:
# 0.0020719287

# %%
import pysindy as ps
from pysindy.differentiation import FiniteDifference
gru_outs, sindy_outs = shred.gru_outputs(test_dataset.X, sindy=True)
differentiation_method = FiniteDifference()

fig, ax = plt.subplots(latent_dim)
for i in range(latent_dim):
    ax[i].plot(gru_outs[1:,0,i].detach().cpu().numpy())

# %%
gru_outs, sindy_outs = shred.gru_outputs(train_dataset.X, sindy=True)
gru_outs = gru_outs[:,0,:]

###############Normalization###############
for i in range(latent_dim):
    gru_outs[:,i] = (gru_outs[:,i] - torch.min(gru_outs[:,i])) / (torch.max(gru_outs[:,i])-torch.min(gru_outs[:,i]))

gru_outs = 2 * gru_outs - 1

###############SINDy discovery###############

x = gru_outs.detach().cpu().numpy()

differentiation_method = ps.differentiation.FiniteDifference()
# differentiation_method = ps.differentiation.SmoothedFiniteDifference()

poly_order = 1

model = ps.SINDy(
    optimizer=ps.STLSQ(threshold=0.25, alpha=0.05),
    differentiation_method=differentiation_method,
    feature_library=ps.PolynomialLibrary(degree=poly_order)
)


model.fit(x, t=1.0/lags, ensemble=False)
model.print()


###############Plot the discovered SINDy model###############

t_train = np.arange(0, train_data_in.shape[0]/lags, 1/lags)
init_cond = np.zeros(latent_dim)
init_cond[:latent_dim] = gru_outs[0,:].detach().cpu().numpy()
x_sim = model.simulate(init_cond, t_train)

fig, ax = plt.subplots(latent_dim)
for i in range(latent_dim):
    ax[i].plot(gru_outs[:,i].detach().cpu().numpy())
    ax[i].plot(x_sim[:,i], "k--", label="model")
# Out:
# (x0)' = -0.398 1 + 5.476 x0 + 2.039 x1 + 6.140 x2
# (x1)' = -0.423 1 + 6.701 x0 + 2.287 x1 + 7.793 x2
# (x2)' = 1.391 1 + -9.255 x0 + -6.043 x1 + -7.690 x2

# %%
#Reload data from the entire training set
gru_outs_train, _ = shred.gru_outputs(train_dataset.X, sindy=True)
gru_outs_train = gru_outs_train[:,0,:]
gru_outs_val, _ = shred.gru_outputs(valid_dataset.X, sindy=True)
gru_outs_val = gru_outs_val[:,0,:]
gru_outs_test, _ = shred.gru_outputs(test_dataset.X, sindy=True)
gru_outs_test = gru_outs_test[:,0,:]

gru_outs_all = np.zeros((Ndata-1, latent_dim))
gru_outs_all[:train_size-1,:] = gru_outs_train.detach().cpu().numpy()
gru_outs_all[train_size : train_size + valid_size-1,:] = gru_outs_val.detach().cpu().numpy()
gru_outs_all[(train_size + valid_size):,:] = gru_outs_test.detach().cpu().numpy()
gru_outs_numpy = gru_outs_train.detach().cpu().numpy()
for i in range(latent_dim):
    gru_outs_all[:,i] = (gru_outs_all[:,i] - np.min(gru_outs_numpy[:,i])) / (np.max(gru_outs_numpy[:,i])-np.min(gru_outs_numpy[:,i]))

gru_outs_all = 2 * gru_outs_all - 1

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from scipy.io import loadmat

###############Normalization###############
gru_outs_test_np = gru_outs_test.detach().cpu().numpy()

for i in range(latent_dim):
    gru_outs_test_np[:, i] = (gru_outs_test_np[:, i] - np.min(gru_outs_numpy[:, i])) / (np.max(gru_outs_numpy[:, i]) - np.min(gru_outs_numpy[:, i]))

gru_outs_test_np = 2 * gru_outs_test_np - 1  # Transform to [-1, 1]

################Forward simulation with the model################
t_test = np.arange(0, test_data_in.shape[0]*1/lags, 1/lags)
init_cond = np.zeros(latent_dim)
init_cond[:latent_dim] = gru_outs_test_np[0, :]
x_sim_test = model.simulate(init_cond, t_test)

# Plotting for each latent dimension: True vs SINDy
fig, ax = plt.subplots(latent_dim, figsize=(10, latent_dim * 3))

for i in range(latent_dim):
#    ax[i].plot(gru_outs_test_np[:, i], label='GRU Signal', linewidth=2)
#    ax[i].plot(x_sim_test[:, i], "k--", label='SINDy Approximation', linewidth=2)
    ax[i].plot(gru_outs_test_np[:, i], linewidth=2)
    ax[i].plot(x_sim_test[:, i], "k--",  linewidth=2)
    
    ax[i].legend()
    ax[i].set_ylabel(f'z_{i+1}')
    ax[i].set_xlabel('Time')

plt.tight_layout()
plt.show()

# %%
###############Predict back in the pixel space###############

# Step 1: Reverse Min-Max scaling for SINDy-simulated data (x_sim_test)
x_sim_test = np.array(x_sim_test)  # Ensure it's a numpy array if needed

# Revert the scaling from [-1, 1] back to [0, 1]
x_sim_test = (x_sim_test + 1) / 2  

# Perform the Min-Max reverse transformation using the original min/max values
for i in range(latent_dim):  
    x_sim_test[:, i] = x_sim_test[:, i] * (np.max(gru_outs_numpy[:, i]) - np.min(gru_outs_numpy[:, i])) + np.min(gru_outs_numpy[:, i])

# Perform the decoder reconstruction using the transformed SINDy-simulated data
latent_pred_sindy = torch.FloatTensor(x_sim_test).cuda()  # Convert to torch tensor for reconstruction

# Pass the SINDy-simulated latent space data through the decoder
output_sindy = shred.linear1(latent_pred_sindy)
output_sindy = shred.dropout(output_sindy)
output_sindy = torch.nn.functional.relu(output_sindy)
output_sindy = shred.linear2(output_sindy)
output_sindy = shred.dropout(output_sindy)
output_sindy = torch.nn.functional.relu(output_sindy)
output_sindy = shred.linear3(output_sindy)

# Detach and convert the reconstructed data back to numpy for visualization
output_sindy_np = sc.inverse_transform(output_sindy.detach().cpu().numpy())
        
# Initialize an empty array with the same shape as the original data
reconstructed_data_sindy = np.zeros_like(n_lat*n_lon)

# %%
# Assuming decoder_model is your decoder（shred）, and timesteps are [50,100,150,200] or any set of timesteps you'd like to plot
timesteps = [10,30,50,70,90,110]  # Define timesteps to plot in testsets
fig, axes = plt.subplots(2, len(timesteps), 
                         figsize=(4 * len(timesteps), 8),
                         subplot_kw={'projection': ccrs.PlateCarree()})


for row in range(2):  
    for col in range(len(timesteps)):

        t = timesteps[col]

        # Copy the SINDy-reconstructed values back to the locations for the current timestep
        reconstructed_data_sindy = output_sindy_np[t, :]  # Use the selected timestep
        #print(np.sum(np.square(output_sindy_np[t,:]-output_sindy_np[t+1, :])))

        if row == 0 :
            field = test_ground_truth[t,:] 
        elif row == 1 :
            field = reconstructed_data_sindy
        #reshape
        field = field.reshape(n_lat, n_lon)  # reshape
        
        #plot fields for ture\prediction results
        ax = axes[row, col]
        im = ax.pcolormesh(lon2d, lat2d, field, shading='auto',
                    transform=ccrs.PlateCarree(), cmap='seismic',vmin=98000,vmax=104000)
        
        # coastline
        ax.coastlines(resolution='110m')
        ax.add_feature(cfeature.LAND, facecolor='lightgray')
        ax.add_feature(cfeature.OCEAN, facecolor='lightblue')
        ax.gridlines(draw_labels=True, linewidth=0.5, color='gray', linestyle='--')
            
        ax.axis('off')

        if row == 0:
            ax.set_title(f"True result at {t}")
        elif row == 1 :
            ax.set_title(f"SINDy-SHRED prediction at {t}")           

        ax.axis('off')
  
           
# Add a single shared colorbar
# Reserve more space at the bottom
plt.tight_layout(rect=[0, 0.03, 1, 1])  # top-left:0, bottom:0.05
    
# Add colorbar below figure, outside subplots
cbar_ax = fig.add_axes([0.2, 0.04, 0.6, 0.02])  # [left, bottom, width, height]
fig.colorbar(im, cax=cbar_ax, orientation='horizontal')
    
plt.show()

# %%
#save model
torch.save(shred.state_dict(), 'SINDy_SHRED_results/shred_model_slp.pt')

import joblib
joblib.dump(model, 'SINDy_SHRED_results/sindy_model_slp.pkl')

joblib.dump(sc, 'SINDy_SHRED_results/minmax_scaler_slp.pkl')

#save results
np.save('SINDy_SHRED_results/x_sim_test_slp.npy', x_sim_test)
np.save('SINDy_SHRED_results/output_sindy_slp.npy', output_sindy_np)
np.save('SINDy_SHRED_results/ground_truth_slp.npy', test_ground_truth)

print("finishing saveing models and results")
# Out:
# finishing saveing models and results
